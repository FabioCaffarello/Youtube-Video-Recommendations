# %% [markdown]
# # IMPORTS

# %%
import math
import numpy  as np
import pandas as pd
import joblib as jb

from scipy.sparse import hstack

from youtube.Youtube   import YoutubeData
from pipeline.Pipeline import DataPipeline

pd.set_option('display.max_columns', 200)

# %%
ytd = YoutubeData()

# %%
params = {
            'base_url': 'https://stats.stackexchange.com/questions/tagged/',
            'tag': 'python',
            'query_filter': 'Votes',
            'max_pages': 50,
            'pagesize': 50,
            'num_videos': 1
        }

# %%
df = ytd.getData(**params)
# Out:
# [download] Downloading playlist: \keras python
# [youtube:search:date] query "\keras python": Downloading page 1
# [youtube:search:date] playlist \keras python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] -1unbql-yCc: Downloading webpage
# [youtube] -1unbql-yCc: Downloading MPD manifest
# [download] Finished downloading playlist: \keras python
# [download] Downloading playlist: \neural-networks python
# [youtube:search:date] query "\neural-networks python": Downloading page 1
# [youtube:search:date] playlist \neural-networks python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] MATq4ATyM1Y: Downloading webpage
# [youtube] MATq4ATyM1Y: Downloading MPD manifest
# [download] Finished downloading playlist: \neural-networks python
# [download] Downloading playlist: \svm python
# [youtube:search:date] query "\svm python": Downloading page 1
# [youtube:search:date] playlist \svm python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] 3jPkSTZbzYM: Downloading webpage
# [youtube] 3jPkSTZbzYM: Downloading MPD manifest
# [download] Finished downloading playlist: \svm python
# [download] Downloading playlist: \cross-validation python
# [youtube:search:date] query "\cross-validation python": Downloading page 1
# [youtube:search:date] playlist \cross-validation python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] tCWZTcKwS7I: Downloading webpage
# [youtube] tCWZTcKwS7I: Downloading MPD manifest
# [download] Finished downloading playlist: \cross-validation python
# [download] Downloading playlist: \scikit-learn python
# [youtube:search:date] query "\scikit-learn python": Downloading page 1
# [youtube:search:date] playlist \scikit-learn python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] RYLuuDMxtDI: Downloading webpage
# [youtube] RYLuuDMxtDI: Downloading MPD manifest
# [download] Finished downloading playlist: \scikit-learn python
# [download] Downloading playlist: \deep-learning python
# [youtube:search:date] query "\deep-learning python": Downloading page 1
# [youtube:search:date] playlist \deep-learning python: Downloading 0 videos
# [download] Finished downloading playlist: \deep-learning python
# [download] Downloading playlist: \pandas python
# [youtube:search:date] query "\pandas python": Downloading page 1
# [youtube:search:date] playlist \pandas python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] z3Sv3ubdcOo: Downloading webpage
# [youtube] z3Sv3ubdcOo: Downloading MPD manifest
# [download] Finished downloading playlist: \pandas python
# [download] Downloading playlist: \clustering python
# [youtube:search:date] query "\clustering python": Downloading page 1
# [youtube:search:date] playlist \clustering python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] fiMIlajdLMY: Downloading webpage
# [youtube] fiMIlajdLMY: Downloading MPD manifest
# [download] Finished downloading playlist: \clustering python
# [download] Downloading playlist: \statsmodels python
# [youtube:search:date] query "\statsmodels python": Downloading page 1
# [youtube:search:date] playlist \statsmodels python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] PMSBxebVqRo: Downloading webpage
# [youtube] PMSBxebVqRo: Downloading MPD manifest
# [download] Finished downloading playlist: \statsmodels python
# [download] Downloading playlist: \pca python
# [youtube:search:date] query "\pca python": Downloading page 1
# [youtube:search:date] playlist \pca python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] Qoh83xF2Trs: Downloading webpage
# [youtube] Qoh83xF2Trs: Downloading MPD manifest
# [download] Finished downloading playlist: \pca python
# [download] Downloading playlist: \random-forest python
# [youtube:search:date] query "\random-forest python": Downloading page 1
# [youtube:search:date] playlist \random-forest python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] aVrlxBwc1os: Downloading webpage
# [youtube] aVrlxBwc1os: Downloading MPD manifest
# [download] Finished downloading playlist: \random-forest python
# [download] Downloading playlist: \logistic python
# [youtube:search:date] query "\logistic python": Downloading page 1
# [youtube:search:date] playlist \logistic python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] km2sOGfJH88: Downloading webpage
# [download] Finished downloading playlist: \logistic python
# [download] Downloading playlist: \machine-learning python
# [youtube:search:date] query "\machine-learning python": Downloading page 1
# [youtube:search:date] playlist \machine-learning python: Downloading 0 videos
# [download] Finished downloading playlist: \machine-learning python
# [download] Downloading playlist: \scipy python
# [youtube:search:date] query "\scipy python": Downloading page 1
# [youtube:search:date] playlist \scipy python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] kIanGE8a98s: Downloading webpage
# [youtube] kIanGE8a98s: Downloading MPD manifest
# [download] Finished downloading playlist: \scipy python
# [download] Downloading playlist: \data-visualization python
# [youtube:search:date] query "\data-visualization python": Downloading page 1
# [youtube:search:date] playlist \data-visualization python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] W3eEPzvuL4Q: Downloading webpage
# [youtube] W3eEPzvuL4Q: Downloading MPD manifest
# [download] Finished downloading playlist: \data-visualization python

# %%
df.head()
# Out:
#              Id                   Uploader                UploaderId  \
# 8   aVrlxBwc1os               RS GIS World  UC9KCRjDcPjexS73DWJbsrVw
# 6   PMSBxebVqRo            Angela Riveroll  UCtTwz1DFBmkeDDhNToJoAuA
# 3   tCWZTcKwS7I               Data Mastery  UCikLKUS0DZWMkukbkYDG49Q
# 10  kIanGE8a98s  Raúl Valerio - Statistics  UCe4UCHmQu92O03Z1fgzUXmQ
# 2   3jPkSTZbzYM               Jazi Designs  UCfT-IVhJc5x7P4DIx9DLgIQ
#
#                                           UploaderUrl  \
# 8   http://www.youtube.com/channel/UC9KCRjDcPjexS7...
# 6   http://www.youtube.com/channel/UCtTwz1DFBmkeDD...
# 3   http://www.youtube.com/channel/UCikLKUS0DZWMku...
# 10  http://www.youtube.com/channel/UCe4UCHmQu92O03...
# 2   http://www.youtube.com/channel/UCfT-IVhJc5x7P4...
#
#                    ChannelId  \
# 8   UC9KCRjDcPjexS73DWJbsrVw
# 6   UCtTwz1DFBmkeDDhNToJoAuA
# 3   UCikLKUS0DZWMkukbkYDG49Q
# 10  UCe4UCHmQu92O03Z1fgzUXmQ
# 2   UCfT-IVhJc5x7P4DIx9DLgIQ
#
#                                            ChannelUrl UploadDate License  \
# 8   http://www.youtube.com/channel/UC9KCRjDcPjexS7...   20201204    None
# 6   http://www.youtube.com/channel/UCtTwz1DFBmkeDD...   20201205    None
# 3   http://www.youtube.com/channel/UCikLKUS0DZWMku...   20201209    None
# 10  http://www.youtube.com/channel/UCe4UCHmQu92O03...   20201211    None
# 2   http://www.youtube.com/channel/UCfT-IVhJc5x7P4...   20201212    None
#
#    Creator                                              Title AltTitle  \
# 8     None               Random Forest Classification in QGIS     None
# 6     None  Parsing Proteomics Data in Python: Graduate Pr...     None
# 3     None  Python für Data Science & Machine Learning #26...     None
# 10    None  V-1: Clustering jerarquico con Python: sklearn...     None
# 2     None          Support Vector Machine (SVM) using python     None
#
#                                            Thumbnails  \
# 8   [{'url': 'https://i.ytimg.com/vi/aVrlxBwc1os/h...
# 6   [{'url': 'https://i.ytimg.com/vi/PMSBxebVqRo/h...
# 3   [{'url': 'https://i.ytimg.com/vi/tCWZTcKwS7I/h...
# 10  [{'url': 'https://i.ytimg.com/vi/kIanGE8a98s/h...
# 2   [{'url': 'https://i.ytimg.com/vi/3jPkSTZbzYM/h...
#
#                                           Description              Categories  \
# 8                                       Random Forest             [Education]
# 6                                                Use         [People & Blogs]
# 3                     Dieser kurze Einwurf zum Thema   [Science & Technology]
# 10  En este super capítulo se ejecuta el descubrim...  [Science & Technology]
# 2   This video is related to Logistic Regression u...  [Science & Technology]
#
#                                                  Tags Subtitles  \
# 8   [Random Forest, RF, QGIS, Qgis, GIS, Classific...        {}
# 6                                                None        {}
# 3   [cross validation, machine learning, hyperpara...        {}
# 10  [python, read, load, science, ciencia, datos, ...        {}
# 2   [data science, artificial intelligence, machin...        {}
#
#    AutomaticCaptions  Duration  AgeLimit Annotations Chapters  \
# 8                 {}     253.0         0        None     None
# 6                 {}     993.0         0        None     None
# 3                 {}     185.0         0        None     None
# 10                {}     929.0         0        None     None
# 2                 {}     183.0         0        None     None
#
#                                      WebpageUrl  ViewCount  LikeCount  \
# 8   https://www.youtube.com/watch?v=aVrlxBwc1os        120        9.0
# 6   https://www.youtube.com/watch?v=PMSBxebVqRo          3        NaN
# 3   https://www.youtube.com/watch?v=tCWZTcKwS7I          2        NaN
# 10  https://www.youtube.com/watch?v=kIanGE8a98s          2        NaN
# 2   https://www.youtube.com/watch?v=3jPkSTZbzYM          2        2.0
#
#    DislikeCount  AverageRating  \
# 8          None            5.0
# 6          None            NaN
# 3          None            NaN
# 10         None            NaN
# 2          None            5.0
#
#                                               Formats IsLive StartTime  \
# 8   [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None
# 6   [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None
# 3   [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None
# 10  [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None
# 2   [{'ext': 'webm', 'format_note': 'DASH audio', ...   None      None
#
#    EndTime Series SeasonNumber EpisodeNumber Track Artist Album ReleaseDate  \
# 8     None   None         None          None  None   None  None        None
# 6     None   None         None          None  None   None  None        None
# 3     None   None         None          None  None   None  None        None
# 10    None   None         None          None  None   None  None        None
# 2     None   None         None          None  None   None  None        None
#
#    ReleaseYear  SubscriberCount Extractor WebpageUrlBasename ExtractorKey  \
# 8         None            981.0   youtube        aVrlxBwc1os      Youtube
# 6         None              NaN   youtube        PMSBxebVqRo      Youtube
# 3         None             14.0   youtube        tCWZTcKwS7I      Youtube
# 10        None            104.0   youtube        kIanGE8a98s      Youtube
# 2         None             40.0   youtube        3jPkSTZbzYM      Youtube
#
#     NEntries                  Playlist                PlaylistId  \
# 8          1     \random-forest python     \random-forest python
# 6          1       \statsmodels python       \statsmodels python
# 3          1  \cross-validation python  \cross-validation python
# 10         1             \scipy python             \scipy python
# 2          1               \svm python               \svm python
#
#    PlaylistTitle PlaylistUploader PlaylistUploaderId  PlaylistIndex  \
# 8           None             None               None              1
# 6           None             None               None              1
# 3           None             None               None              1
# 10          None             None               None              1
# 2           None             None               None              1
#
#                                             Thumbnail    DisplayId  \
# 8   https://i.ytimg.com/vi_webp/aVrlxBwc1os/maxres...  aVrlxBwc1os
# 6   https://i.ytimg.com/vi_webp/PMSBxebVqRo/maxres...  PMSBxebVqRo
# 3   https://i.ytimg.com/vi_webp/tCWZTcKwS7I/maxres...  tCWZTcKwS7I
# 10  https://i.ytimg.com/vi_webp/kIanGE8a98s/maxres...  kIanGE8a98s
# 2   https://i.ytimg.com/vi/3jPkSTZbzYM/hqdefault.j...  3jPkSTZbzYM
#
#    RequestedSubtitles                                   RequestedFormats  \
# 8                None  [{'ext': 'mp4', 'height': 1080, 'format_note':...
# 6                None  [{'ext': 'webm', 'height': 682, 'format_note':...
# 3                None  [{'ext': 'webm', 'height': 1080, 'format_note'...
# 10               None  [{'ext': 'webm', 'height': 720, 'format_note':...
# 2                None  [{'ext': 'webm', 'height': 720, 'format_note':...
#
#                                                Format FormatId   Ext  Width  \
# 8   137 - 1920x1080 (DASH video)+140 - audio only ...  137+140   mp4   1920
# 6   247 - 1280x682 (DASH video)+140 - audio only (...  247+140  webm   1280
# 3   248 - 1920x1080 (DASH video)+140 - audio only ...  248+140  webm   1920
# 10  302 - 1280x720 (DASH video)+140 - audio only (...  302+140  webm   1280
# 2   247 - 1276x720 (DASH video)+140 - audio only (...  247+140  webm   1276
#
#     Height Resolution  Fps       Vcodec   Vbr StretchedRatio     Acodec  Abr  \
# 8     1080       None   25  avc1.640028  None           None  mp4a.40.2  128
# 6      682       None   29          vp9  None           None  mp4a.40.2  128
# 3     1080       None   30          vp9  None           None  mp4a.40.2  128
# 10     720       None   60          vp9  None           None  mp4a.40.2  128
# 2      720       None   30          vp9  None           None  mp4a.40.2  128
#
#                Query          TagStack  IncidenceStack  VotesStack  \
# 8      random-forest     random-forest              99         281
# 6        statsmodels       statsmodels             101         311
# 3   cross-validation  cross-validation              59         235
# 10             scipy             scipy              96         201
# 2                svm               svm              71         234
#
#     AnswerStack  ViewsStack  ViewsPerIncidenceStack
# 8           100      282123             2849.727273
# 6           118      358851             3552.980198
# 3            65      241748             4097.423729
# 10           99      235203             2450.031250
# 2            86      373003             5253.563380

# %%
pipeline = DataPipeline()

# %%
dfFeatures = pipeline.featureSelection(df)
dfFeatures = pipeline.titleVectorizer(dfFeatures, df['Title'])
predict = pipeline.predict(df, dfFeatures)
# Out:
# C:\Users\fabio\Anaconda3\lib\site-packages\lightgbm\basic.py:597: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')

# %%
predict.head()
# Out:
#                                                 Title  \
# 8                Random Forest Classification in QGIS
# 6   Parsing Proteomics Data in Python: Graduate Pr...
# 3   Python für Data Science & Machine Learning #26...
# 10  V-1: Clustering jerarquico con Python: sklearn...
# 2           Support Vector Machine (SVM) using python
#
#                                      WebpageUrl   Predict
# 8   https://www.youtube.com/watch?v=aVrlxBwc1os  0.349168
# 6   https://www.youtube.com/watch?v=PMSBxebVqRo  0.481556
# 3   https://www.youtube.com/watch?v=tCWZTcKwS7I  0.383153
# 10  https://www.youtube.com/watch?v=kIanGE8a98s  0.450134
# 2   https://www.youtube.com/watch?v=3jPkSTZbzYM  0.374656

# %%
## DB Starter

# %%
import runBackend # Python file
import sqlite3 as sql

if __name__ == '__main__':
    with sql.connect(runBackend.dbName) as conn:
        cur = conn.cursor()
        # Create Table
        cur.execute('''CREATE TABLE videos (Id TEXT UNIQUE
                                                ,Title TEXT
                                                ,WebpageUrl TEXT UNIQUE
                                                ,LikeCount INTEGER
                                                ,UploadDate DATE
                                                ,Duration INTEGER
                                                ,IncidenceStack REAL
                                                ,VotesStack REAL
                                                ,ViewCount REAL
                                                ,TagStack TEXT
                                                )''')
        con.commit()
    runBackend.updateDB()

# %%
## runBackend

# %%
import pandas  as pd
import sqlite3 as sql

from youtube.Yotutube import YoutubeData

dbName = 'youtubeVideo.db'


def updateDB():
    
    params = {
                'base_url': 'https://stats.stackexchange.com/questions/tagged/',
                'tag': 'python',
                'query_filter': 'Votes',
                'max_pages': 50,
                'pagesize': 50,
                'num_videos': 1
            }
    
    ydt = YoutubeData()
    data = ydt.getData(**params)
    with sql.connect(dbName) as conn:
        data[['Id', 'Title', 'WebpageUrl', 'LikeCount', 'UploadDate', 'Duration', 'IncidenceStack', 'VotesStack', 'ViewCount', 'TagStack']]
        data.to_sql(name=videos, con=conn, if_exists='replace', index=False)
        cur = conn.cursor()
        conn.commit()
    return True
