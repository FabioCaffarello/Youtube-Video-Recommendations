# %% [markdown]
# # IMPORTS

# %%
import math
import numpy  as np
import pandas as pd
import joblib as jb

from scipy.sparse import hstack

from youtube.Youtube   import YoutubeData
from pipeline.Pipeline import DataPipeline

pd.set_option('display.max_columns', 200)

# %%
ytd = YoutubeData()

# %%
params = {
            'base_url': 'https://stats.stackexchange.com/questions/tagged/',
            'tag': 'python',
            'query_filter': 'Votes',
            'max_pages': 50,
            'pagesize': 50,
            'num_videos': 1
        }

# %%
df = ytd.getData(**params)
# Out:
# [download] Downloading playlist: \keras python
# [youtube:search:date] query "\keras python": Downloading page 1
# [youtube:search:date] playlist \keras python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] -1unbql-yCc: Downloading webpage
# [youtube] -1unbql-yCc: Downloading MPD manifest
# [download] Finished downloading playlist: \keras python
# [download] Downloading playlist: \neural-networks python
# [youtube:search:date] query "\neural-networks python": Downloading page 1
# [youtube:search:date] playlist \neural-networks python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] MATq4ATyM1Y: Downloading webpage
# [youtube] MATq4ATyM1Y: Downloading MPD manifest
# [download] Finished downloading playlist: \neural-networks python
# [download] Downloading playlist: \svm python
# [youtube:search:date] query "\svm python": Downloading page 1
# [youtube:search:date] playlist \svm python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] 3jPkSTZbzYM: Downloading webpage
# [youtube] 3jPkSTZbzYM: Downloading MPD manifest
# [download] Finished downloading playlist: \svm python
# [download] Downloading playlist: \cross-validation python
# [youtube:search:date] query "\cross-validation python": Downloading page 1
# [youtube:search:date] playlist \cross-validation python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] tCWZTcKwS7I: Downloading webpage
# [youtube] tCWZTcKwS7I: Downloading MPD manifest
# [download] Finished downloading playlist: \cross-validation python
# [download] Downloading playlist: \scikit-learn python
# [youtube:search:date] query "\scikit-learn python": Downloading page 1
# [youtube:search:date] playlist \scikit-learn python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] RYLuuDMxtDI: Downloading webpage
# [youtube] RYLuuDMxtDI: Downloading MPD manifest
# [download] Finished downloading playlist: \scikit-learn python
# [download] Downloading playlist: \deep-learning python
# [youtube:search:date] query "\deep-learning python": Downloading page 1
# [youtube:search:date] playlist \deep-learning python: Downloading 0 videos
# [download] Finished downloading playlist: \deep-learning python
# [download] Downloading playlist: \pandas python
# [youtube:search:date] query "\pandas python": Downloading page 1
# [youtube:search:date] playlist \pandas python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] XXci8JlV5MU: Downloading webpage
# ERROR: Premieres in 3 hours
# [download] Finished downloading playlist: \pandas python
# [download] Downloading playlist: \clustering python
# [youtube:search:date] query "\clustering python": Downloading page 1
# [youtube:search:date] playlist \clustering python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] fiMIlajdLMY: Downloading webpage
# [youtube] fiMIlajdLMY: Downloading MPD manifest
# [download] Finished downloading playlist: \clustering python
# [download] Downloading playlist: \statsmodels python
# [youtube:search:date] query "\statsmodels python": Downloading page 1
# [youtube:search:date] playlist \statsmodels python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] PMSBxebVqRo: Downloading webpage
# [youtube] PMSBxebVqRo: Downloading MPD manifest
# [download] Finished downloading playlist: \statsmodels python
# [download] Downloading playlist: \pca python
# [youtube:search:date] query "\pca python": Downloading page 1
# [youtube:search:date] playlist \pca python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] Qoh83xF2Trs: Downloading webpage
# [youtube] Qoh83xF2Trs: Downloading MPD manifest
# [download] Finished downloading playlist: \pca python
# [download] Downloading playlist: \random-forest python
# [youtube:search:date] query "\random-forest python": Downloading page 1
# [youtube:search:date] playlist \random-forest python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] 2F9QZLvnENQ: Downloading webpage
# [youtube] 2F9QZLvnENQ: Downloading MPD manifest
# [download] Finished downloading playlist: \random-forest python
# [download] Downloading playlist: \logistic python
# [youtube:search:date] query "\logistic python": Downloading page 1
# [youtube:search:date] playlist \logistic python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] km2sOGfJH88: Downloading webpage
# [download] Finished downloading playlist: \logistic python
# [download] Downloading playlist: \machine-learning python
# [youtube:search:date] query "\machine-learning python": Downloading page 1
# [youtube:search:date] playlist \machine-learning python: Downloading 0 videos
# [download] Finished downloading playlist: \machine-learning python
# [download] Downloading playlist: \scipy python
# [youtube:search:date] query "\scipy python": Downloading page 1
# [youtube:search:date] playlist \scipy python: Downloading 1 videos
# [download] Downloading video 1 of 1
# [youtube] kIanGE8a98s: Downloading webpage
# [youtube] kIanGE8a98s: Downloading MPD manifest
# [download] Finished downloading playlist: \scipy python
# [download] Downloading playlist: \data-visualization python
# [youtube:search:date] query "\data-visualization python": Downloading page 1

# %%
df.head()
# Out:
#             Id                   Uploader                UploaderId  \
# 5  PMSBxebVqRo            Angela Riveroll  UCtTwz1DFBmkeDDhNToJoAuA
# 7  2F9QZLvnENQ       ProgrammingKnowledge      ProgrammingKnowledge
# 2  tCWZTcKwS7I               Data Mastery  UCikLKUS0DZWMkukbkYDG49Q
# 9  kIanGE8a98s  Raúl Valerio - Statistics  UCe4UCHmQu92O03Z1fgzUXmQ
# 4  fiMIlajdLMY               Jazi Designs  UCfT-IVhJc5x7P4DIx9DLgIQ
#
#                                          UploaderUrl  \
# 5  http://www.youtube.com/channel/UCtTwz1DFBmkeDD...
# 7   http://www.youtube.com/user/ProgrammingKnowledge
# 2  http://www.youtube.com/channel/UCikLKUS0DZWMku...
# 9  http://www.youtube.com/channel/UCe4UCHmQu92O03...
# 4  http://www.youtube.com/channel/UCfT-IVhJc5x7P4...
#
#                   ChannelId  \
# 5  UCtTwz1DFBmkeDDhNToJoAuA
# 7  UCs6nmQViDpUw0nuIx9c_WvA
# 2  UCikLKUS0DZWMkukbkYDG49Q
# 9  UCe4UCHmQu92O03Z1fgzUXmQ
# 4  UCfT-IVhJc5x7P4DIx9DLgIQ
#
#                                           ChannelUrl UploadDate License  \
# 5  http://www.youtube.com/channel/UCtTwz1DFBmkeDD...   20201205    None
# 7  http://www.youtube.com/channel/UCs6nmQViDpUw0n...   20201206    None
# 2  http://www.youtube.com/channel/UCikLKUS0DZWMku...   20201209    None
# 9  http://www.youtube.com/channel/UCe4UCHmQu92O03...   20201211    None
# 4  http://www.youtube.com/channel/UCfT-IVhJc5x7P4...   20201212    None
#
#   Creator                                              Title AltTitle  \
# 5    None  Parsing Proteomics Data in Python: Graduate Pr...     None
# 7    None  Random Forest Algorithm Tutorial | Random Fore...     None
# 2    None  Python für Data Science & Machine Learning #26...     None
# 9    None  V-1: Clustering jerarquico con Python: sklearn...     None
# 4    None                    K-Means Clustering using python     None
#
#                                           Thumbnails  \
# 5  [{'url': 'https://i.ytimg.com/vi/PMSBxebVqRo/h...
# 7  [{'url': 'https://i.ytimg.com/vi/2F9QZLvnENQ/h...
# 2  [{'url': 'https://i.ytimg.com/vi/tCWZTcKwS7I/h...
# 9  [{'url': 'https://i.ytimg.com/vi/kIanGE8a98s/h...
# 4  [{'url': 'https://i.ytimg.com/vi/fiMIlajdLMY/h...
#
#                                          Description              Categories  \
# 5                                               Use         [People & Blogs]
# 7                   In this video, we'll talk about              [Education]
# 2                    Dieser kurze Einwurf zum Thema   [Science & Technology]
# 9  En este super capítulo se ejecuta el descubrim...  [Science & Technology]
# 4                  This video is related to K Means   [Science & Technology]
#
#                                                 Tags Subtitles  \
# 5                                               None        {}
# 7  [ml, so, machine learning, artificial intellig...        {}
# 2  [cross validation, machine learning, hyperpara...        {}
# 9  [python, read, load, science, ciencia, datos, ...        {}
# 4  [data science, artificial intelligence, machin...        {}
#
#   AutomaticCaptions  Duration  AgeLimit Annotations Chapters  \
# 5                {}     993.0         0        None     None
# 7                {}     882.0         0        None     None
# 2                {}     185.0         0        None     None
# 9                {}     929.0         0        None     None
# 4                {}     187.0         0        None     None
#
#                                     WebpageUrl  ViewCount  LikeCount  \
# 5  https://www.youtube.com/watch?v=PMSBxebVqRo          3        NaN
# 7  https://www.youtube.com/watch?v=2F9QZLvnENQ          1       50.0
# 2  https://www.youtube.com/watch?v=tCWZTcKwS7I          2        NaN
# 9  https://www.youtube.com/watch?v=kIanGE8a98s          2        NaN
# 4  https://www.youtube.com/watch?v=fiMIlajdLMY         14        2.0
#
#    DislikeCount  AverageRating  \
# 5           NaN            NaN
# 7           2.0       4.846154
# 2           NaN            NaN
# 9           NaN            NaN
# 4           NaN       5.000000
#
#                                              Formats IsLive StartTime EndTime  \
# 5  [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None    None
# 7  [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None    None
# 2  [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None    None
# 9  [{'ext': 'm4a', 'format_note': 'DASH audio', '...   None      None    None
# 4  [{'ext': 'webm', 'format_note': 'DASH audio', ...   None      None    None
#
#   Series SeasonNumber EpisodeNumber Track Artist Album ReleaseDate  \
# 5   None         None          None  None   None  None        None
# 7   None         None          None  None   None  None        None
# 2   None         None          None  None   None  None        None
# 9   None         None          None  None   None  None        None
# 4   None         None          None  None   None  None        None
#
#   ReleaseYear  SubscriberCount Extractor WebpageUrlBasename ExtractorKey  \
# 5        None              NaN   youtube        PMSBxebVqRo      Youtube
# 7        None        1300000.0   youtube        2F9QZLvnENQ      Youtube
# 2        None             14.0   youtube        tCWZTcKwS7I      Youtube
# 9        None            104.0   youtube        kIanGE8a98s      Youtube
# 4        None             40.0   youtube        fiMIlajdLMY      Youtube
#
#    NEntries                  Playlist                PlaylistId PlaylistTitle  \
# 5         1       \statsmodels python       \statsmodels python          None
# 7         1     \random-forest python     \random-forest python          None
# 2         1  \cross-validation python  \cross-validation python          None
# 9         1             \scipy python             \scipy python          None
# 4         1        \clustering python        \clustering python          None
#
#   PlaylistUploader PlaylistUploaderId  PlaylistIndex  \
# 5             None               None              1
# 7             None               None              1
# 2             None               None              1
# 9             None               None              1
# 4             None               None              1
#
#                                            Thumbnail    DisplayId  \
# 5  https://i.ytimg.com/vi_webp/PMSBxebVqRo/maxres...  PMSBxebVqRo
# 7  https://i.ytimg.com/vi/2F9QZLvnENQ/maxresdefau...  2F9QZLvnENQ
# 2  https://i.ytimg.com/vi_webp/tCWZTcKwS7I/maxres...  tCWZTcKwS7I
# 9  https://i.ytimg.com/vi_webp/kIanGE8a98s/maxres...  kIanGE8a98s
# 4  https://i.ytimg.com/vi/fiMIlajdLMY/hqdefault.j...  fiMIlajdLMY
#
#   RequestedSubtitles                                   RequestedFormats  \
# 5               None  [{'ext': 'webm', 'height': 682, 'format_note':...
# 7               None  [{'ext': 'webm', 'height': 720, 'format_note':...
# 2               None  [{'ext': 'webm', 'height': 1080, 'format_note'...
# 9               None  [{'ext': 'webm', 'height': 720, 'format_note':...
# 4               None  [{'ext': 'webm', 'height': 720, 'format_note':...
#
#                                               Format FormatId   Ext  Width  \
# 5  247 - 1280x682 (DASH video)+140 - audio only (...  247+140  webm   1280
# 7  247 - 1152x720 (DASH video)+251 - audio only (...  247+251  webm   1152
# 2  248 - 1920x1080 (DASH video)+140 - audio only ...  248+140  webm   1920
# 9  302 - 1280x720 (DASH video)+140 - audio only (...  302+140  webm   1280
# 4  247 - 1276x720 (DASH video)+140 - audio only (...  247+140  webm   1276
#
#    Height Resolution  Fps Vcodec   Vbr StretchedRatio     Acodec  Abr  \
# 5     682       None   29    vp9  None           None  mp4a.40.2  128
# 7     720       None   30    vp9  None           None       opus  160
# 2    1080       None   30    vp9  None           None  mp4a.40.2  128
# 9     720       None   60    vp9  None           None  mp4a.40.2  128
# 4     720       None   30    vp9  None           None  mp4a.40.2  128
#
#               Query          TagStack  IncidenceStack  VotesStack  \
# 5       statsmodels       statsmodels             101         311
# 7     random-forest     random-forest              99         281
# 2  cross-validation  cross-validation              59         235
# 9             scipy             scipy              96         201
# 4        clustering        clustering              69         195
#
#    AnswerStack  ViewsStack  ViewsPerIncidenceStack
# 5          118      358846             3552.930693
# 7          100      282121             2849.707071
# 2           65      241748             4097.423729
# 9           99      235201             2450.010417
# 4           78      249304             3613.101449

# %%
# class DataPipeline(object):
    
#     def __init__(self):
#         self.home_path = 'D:/01-DataScience/04-Projetos/00-Git/Youtube-Video-Recommendations/webapp/'
#         self.titleVec  = jb.load(open(self.home_path + 'parameter/titleVec.pkl.z', 'rb'))
#         self.modelLGBM = jb.load(open(self.home_path + 'model/modelLgbm.pkl.z', 'rb'))
#         self.modelRf   = jb.load(open(self.home_path + 'model/modelRf.pkl.z', 'rb'))

#     def dataCleaningRaw(self, df):
#         df['LikeCount'] = df['LikeCount'].apply(lambda row: 0 if math.isnan(row) else row)
#         df['UploadDate'] = pd.to_datetime(df['UploadDate'])
#         df['DaysSincePublication'] = (pd.to_datetime('2021-01-01') - df['UploadDate']) / np.timedelta64(1,'D')
#         return df



#     def dataCleaning(self, dfFeatures):   
#         dfFeatures['ViewCountIncidenceStack'].fillna(dfFeatures['ViewCountIncidenceStack'].mean(), inplace=True)
#         dfFeatures['VotesStackLikeCount'].fillna(dfFeatures['VotesStackLikeCount'].mean(), inplace=True)
#         return dfFeatures



#     def featureSelection(self, df):
#         df = DataPipeline.dataCleaningRaw(self, df)

#         dfFeatures = pd.DataFrame(index=df.index)

#         dfFeatures['ViewsPerDay'] = df['ViewCount'] / df['DaysSincePublication']

#         dfFeatures['Duration'] = df['Duration']

#         dfFeatures['ViewCountIncidenceStack'] = df['ViewCount'] / df['IncidenceStack']

#         dfFeatures['VotesStackLikeCount'] = df['VotesStack'] * df['LikeCount']

#         dfFeatures = DataPipeline.dataCleaning(self, dfFeatures)
#         return dfFeatures

#     def titleVectorizer(self, df, titleSeries):
#         titleBowVec = self.titleVec.transform(titleSeries)
#         dataWTitle = hstack([df, titleBowVec])
#         return dataWTitle
    
#     def predict(self, orinalDataset, dataWTitle):
#         modelLGBM = self.modelLGBM
#         modelRf = self.modelRf
#         pLgbm = modelLGBM.predict_proba(dataWTitle)[:,1]
#         pRf = modelRf.predict_proba(dataWTitle)[:,1]
#         pred = 0.5*pLgbm + 0.5*pRf
#         dfResults = df[['Title', 'WebpageUrl']].copy()
#         dfResults['Predict'] = pred
#         return dfResults

# %%
pipeline = DataPipeline()

# %%
dfFeatures = pipeline.featureSelection(df)
dfFeatures = pipeline.titleVectorizer(dfFeatures, df['Title'])
predict = pipeline.predict(df, dfFeatures)
# Out:
# C:\Users\fabio\Anaconda3\lib\site-packages\lightgbm\basic.py:597: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e4c1808161e3> in <module>
#       1 dfFeatures = pipeline.featureSelection(df)
#       2 dfFeatures = pipeline.titleVectorizer(dfFeatures, df['Title'])
# ----> 3 predict = pipeline.predict(df, dfFeatures)
#
# D:\01-DataScience\04-Projetos\00-Git\Youtube-Video-Recommendations\webapp\pipeline\Pipeline.py in predict(self, orinalDataset, dataWTitle)
#      57         pRf = modelRf.predict_proba(dataWTitle)[:,1]
#      58         pred = 0.5*pLgbm + 0.5*pRf
# ---> 59         dfResults = df[['Title', 'WebpageUrl']].copy()
#      60         dfResults['Predict'] = pred
#      61         return dfResults
#
# NameError: name 'df' is not defined

# %%
predict.head()
# Out:
#                                                 Title  \
# 6   Parsing Proteomics Data in Python: Graduate Pr...
# 8   Random Forest Algorithm Tutorial | Random Fore...
# 3   Python für Data Science & Machine Learning #26...
# 10  V-1: Clustering jerarquico con Python: sklearn...
# 2           Support Vector Machine (SVM) using python
#
#                                      WebpageUrl   Predict
# 6   https://www.youtube.com/watch?v=PMSBxebVqRo  0.481556
# 8   https://www.youtube.com/watch?v=2F9QZLvnENQ  0.423790
# 3   https://www.youtube.com/watch?v=tCWZTcKwS7I  0.383153
# 10  https://www.youtube.com/watch?v=kIanGE8a98s  0.450134
# 2   https://www.youtube.com/watch?v=3jPkSTZbzYM  0.374656
