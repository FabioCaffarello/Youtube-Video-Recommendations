# %% [markdown]
# # IMPORTS

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import inflection
import re
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ## Load Data

# %%
dfRaw1 = pd.read_csv('../Data/youtube_dlc/YouTubeStackExchangeQueryRaw.csv', parse_dates=['upload_date'])

# %%
dfRaw1.sample(5)
# Out:
#                id          uploader               uploader_id  \
# 4002  v8GA28j-i3Y       Tech master  UCmcsEEEGcyPABWqJxiDfJtw
# 2415  nmF0OTSl3Lw       Packt Video                 packt1000
# 3775  TalK3fKBzno   DWBIADDA VIDEOS  UCPy4dc8H1R_CjttiFcrROKA
# 1610  soCd8UMsr4Y  PyPower Projects  UCBA-8a6ZuWTtjs4tDGEIdOA
# 1841  VvCKnVklXng          Mark Jay  UC2W0aQEPNpU6XrkFCYifRFQ
#
#                                            uploader_url  \
# 4002  http://www.youtube.com/channel/UCmcsEEEGcyPABW...
# 2415              http://www.youtube.com/user/packt1000
# 3775  http://www.youtube.com/channel/UCPy4dc8H1R_Cjt...
# 1610  http://www.youtube.com/channel/UCBA-8a6ZuWTtjs...
# 1841  http://www.youtube.com/channel/UC2W0aQEPNpU6Xr...
#
#                     channel_id  \
# 4002  UCmcsEEEGcyPABWqJxiDfJtw
# 2415  UC3VydBGBl132baPCLeDspMQ
# 3775  UCPy4dc8H1R_CjttiFcrROKA
# 1610  UCBA-8a6ZuWTtjs4tDGEIdOA
# 1841  UC2W0aQEPNpU6XrkFCYifRFQ
#
#                                             channel_url upload_date  license  \
# 4002  http://www.youtube.com/channel/UCmcsEEEGcyPABW...  2020-07-12      NaN
# 2415  http://www.youtube.com/channel/UC3VydBGBl132ba...  2019-04-05      NaN
# 3775  http://www.youtube.com/channel/UCPy4dc8H1R_Cjt...  2018-09-26      NaN
# 1610  http://www.youtube.com/channel/UCBA-8a6ZuWTtjs...  2020-06-22      NaN
# 1841  http://www.youtube.com/channel/UC2W0aQEPNpU6Xr...  2017-09-04      NaN
#
#      creator                                              title alt_title  \
# 4002     NaN  Python NumPy Tutorial | NumPy Array | How to c...       NaN
# 2415     NaN  Hands-On Artificial Intelligence with Keras an...       NaN
# 3775     NaN  APPLY JOINS INNER LEFT RIGHT OUTER WITH PYTHON...       NaN
# 1610     NaN  'Special Function' in Scipy | Scipy Python Tut...       NaN
# 1841     NaN  Root Finding with python and Jupyter! (pt.2) S...       NaN
#
#                                              thumbnails  \
# 4002  [{'url': 'https://i.ytimg.com/vi/v8GA28j-i3Y/h...
# 2415  [{'url': 'https://i.ytimg.com/vi/nmF0OTSl3Lw/h...
# 3775  [{'url': 'https://i.ytimg.com/vi/TalK3fKBzno/h...
# 1610  [{'url': 'https://i.ytimg.com/vi/soCd8UMsr4Y/h...
# 1841  [{'url': 'https://i.ytimg.com/vi/VvCKnVklXng/h...
#
#                                             description  \
# 4002  Links :- Download Notes :- https://drive.googl...
# 2415  This video tutorial has been taken from Hands-...
# 3775                          How to apply joins using
# 1610        PyPower Projects - Experience The Power Of
# 1841                        In this video, we will use
#
#                     categories  \
# 4002             ['Education']
# 2415  ['Science & Technology']
# 3775             ['Education']
# 1610             ['Education']
# 1841             ['Education']
#
#                                                    tags subtitles  \
# 4002                                                NaN        {}
# 2415  ['Artifical Intelligence', 'Keras', 'Python', ...        {}
# 3775  ['dwbiadda', 'python pandas tutorial', 'pandas...        {}
# 1610  ['python', 'artificial intelligence', 'face re...        {}
# 1841  ['scipy', 'root finding', 'numpy', 'python', '...        {}
#
#      automatic_captions  duration  age_limit  annotations  chapters  \
# 4002                 {}     725.0          0          NaN       NaN
# 2415                 {}     369.0          0          NaN       NaN
# 3775                 {}     641.0          0          NaN       NaN
# 1610                 {}     252.0          0          NaN       NaN
# 1841                 {}     462.0          0          NaN       NaN
#
#                                       webpage_url  view_count  like_count  \
# 4002  https://www.youtube.com/watch?v=v8GA28j-i3Y          87        37.0
# 2415  https://www.youtube.com/watch?v=nmF0OTSl3Lw          30         2.0
# 3775  https://www.youtube.com/watch?v=TalK3fKBzno           3        33.0
# 1610  https://www.youtube.com/watch?v=soCd8UMsr4Y          55         4.0
# 1841  https://www.youtube.com/watch?v=VvCKnVklXng           5        89.0
#
#       dislike_count  average_rating  \
# 4002            NaN        5.000000
# 2415            NaN        5.000000
# 3775            2.0        4.882353
# 1610            NaN        5.000000
# 1841            2.0        4.955555
#
#                                                 formats  is_live  start_time  \
# 4002  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 2415  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 3775  [{'format_id': '249', 'url': 'https://r1---sn-...      NaN         NaN
# 1610  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 1841  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
#
#       end_time  series  season_number  episode_number track artist album  \
# 4002       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 2415       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 3775       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 1610       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 1841       NaN     NaN            NaN             NaN   NaN    NaN   NaN
#
#       release_date  release_year  subscriber_count extractor  \
# 4002           NaN           NaN             291.0   youtube
# 2415           NaN           NaN           67600.0   youtube
# 3775           NaN           NaN            8460.0   youtube
# 1610           NaN           NaN            1530.0   youtube
# 1841           NaN           NaN           19400.0   youtube
#
#      webpage_url_basename extractor_key  n_entries        playlist  \
# 4002          v8GA28j-i3Y       Youtube        479   \numpy python
# 2415          nmF0OTSl3Lw       Youtube        493   \keras python
# 3775          TalK3fKBzno       Youtube        508  \pandas python
# 1610          soCd8UMsr4Y       Youtube        468   \scipy python
# 1841          VvCKnVklXng       Youtube        468   \scipy python
#
#          playlist_id  playlist_title  playlist_uploader  playlist_uploader_id  \
# 4002   \numpy python             NaN                NaN                   NaN
# 2415   \keras python             NaN                NaN                   NaN
# 3775  \pandas python             NaN                NaN                   NaN
# 1610   \scipy python             NaN                NaN                   NaN
# 1841   \scipy python             NaN                NaN                   NaN
#
#       playlist_index                                          thumbnail  \
# 4002             182  https://i.ytimg.com/vi/v8GA28j-i3Y/maxresdefau...
# 2415             363  https://i.ytimg.com/vi_webp/nmF0OTSl3Lw/maxres...
# 3775             463  https://i.ytimg.com/vi_webp/TalK3fKBzno/maxres...
# 1610              86  https://i.ytimg.com/vi_webp/soCd8UMsr4Y/maxres...
# 1841             317  https://i.ytimg.com/vi_webp/VvCKnVklXng/maxres...
#
#        display_id  requested_subtitles  \
# 4002  v8GA28j-i3Y                  NaN
# 2415  nmF0OTSl3Lw                  NaN
# 3775  TalK3fKBzno                  NaN
# 1610  soCd8UMsr4Y                  NaN
# 1841  VvCKnVklXng                  NaN
#
#                                       requested_formats  \
# 4002  [{'ext': 'mp4', 'height': 720, 'format_note': ...
# 2415  [{'ext': 'webm', 'height': 1080, 'format_note'...
# 3775  [{'format_id': '248', 'url': 'https://r1---sn-...
# 1610  [{'ext': 'webm', 'height': 720, 'format_note':...
# 1841  [{'ext': 'mp4', 'height': 1080, 'format_note':...
#
#                                                  format format_id   ext  \
# 4002  136 - 1280x720 (DASH video)+140 - audio only (...   136+140   mp4
# 2415  248 - 1920x1080 (DASH video)+140 - audio only ...   248+140  webm
# 3775    248 - 1920x1080 (1080p)+140 - audio only (tiny)   248+140  webm
# 1610  247 - 1280x720 (DASH video)+251 - audio only (...   247+251  webm
# 1841  299 - 1920x1080 (DASH video)+140 - audio only ...   299+140   mp4
#
#       width  height  resolution  fps       vcodec  vbr  stretched_ratio  \
# 4002   1280     720         NaN   30  avc1.64001f  NaN              NaN
# 2415   1920    1080         NaN   30          vp9  NaN              NaN
# 3775   1920    1080         NaN   29          vp9  NaN              NaN
# 1610   1280     720         NaN   30          vp9  NaN              NaN
# 1841   1920    1080         NaN   60  avc1.64001e  NaN              NaN
#
#          acodec    abr   query  days_since_publication
# 4002  mp4a.40.2  128.0   numpy                   173.0
# 2415  mp4a.40.2  128.0   keras                   637.0
# 3775  mp4a.40.2  128.0  pandas                   828.0
# 1610       opus  160.0   scipy                   193.0
# 1841  mp4a.40.2  128.0   scipy                  1215.0

# %% [markdown]
# # DESCRIPTION OF THE DATA

# %%
dfRaw2 = dfRaw1.copy()

# %%
dfRaw2.columns
# Out:
# Index(['id', 'uploader', 'uploader_id', 'uploader_url', 'channel_id',
#        'channel_url', 'upload_date', 'license', 'creator', 'title',
#        'alt_title', 'thumbnails', 'description', 'categories', 'tags',
#        'subtitles', 'automatic_captions', 'duration', 'age_limit',
#        'annotations', 'chapters', 'webpage_url', 'view_count', 'like_count',
#        'dislike_count', 'average_rating', 'formats', 'is_live', 'start_time',
#        'end_time', 'series', 'season_number', 'episode_number', 'track',
#        'artist', 'album', 'release_date', 'release_year', 'subscriber_count',
#        'extractor', 'webpage_url_basename', 'extractor_key', 'n_entries',
#        'playlist', 'playlist_id', 'playlist_title', 'playlist_uploader',
#        'playlist_uploader_id', 'playlist_index', 'thumbnail', 'display_id',
#        'requested_subtitles', 'requested_formats', 'format', 'format_id',
#        'ext', 'width', 'height', 'resolution', 'fps', 'vcodec', 'vbr',
#        'stretched_ratio', 'acodec', 'abr', 'query', 'days_since_publication'],
#       dtype='object')

# %% [markdown]
# ## Rename Columns

# %%
camelize = lambda col: inflection.camelize(col)

newColumns = list(map(camelize, dfRaw2.columns))

# rename
dfRaw2.columns = newColumns

# %%
dfRaw2.columns
# Out:
# Index(['Id', 'Uploader', 'UploaderId', 'UploaderUrl', 'ChannelId',
#        'ChannelUrl', 'UploadDate', 'License', 'Creator', 'Title', 'AltTitle',
#        'Thumbnails', 'Description', 'Categories', 'Tags', 'Subtitles',
#        'AutomaticCaptions', 'Duration', 'AgeLimit', 'Annotations', 'Chapters',
#        'WebpageUrl', 'ViewCount', 'LikeCount', 'DislikeCount', 'AverageRating',
#        'Formats', 'IsLive', 'StartTime', 'EndTime', 'Series', 'SeasonNumber',
#        'EpisodeNumber', 'Track', 'Artist', 'Album', 'ReleaseDate',
#        'ReleaseYear', 'SubscriberCount', 'Extractor', 'WebpageUrlBasename',
#        'ExtractorKey', 'NEntries', 'Playlist', 'PlaylistId', 'PlaylistTitle',
#        'PlaylistUploader', 'PlaylistUploaderId', 'PlaylistIndex', 'Thumbnail',
#        'DisplayId', 'RequestedSubtitles', 'RequestedFormats', 'Format',
#        'FormatId', 'Ext', 'Width', 'Height', 'Resolution', 'Fps', 'Vcodec',
#        'Vbr', 'StretchedRatio', 'Acodec', 'Abr', 'Query',
#        'DaysSincePublication'],
#       dtype='object')

# %% [markdown]
# ## Columns Filter

# %%
columns = ['Id', 'Uploader', 'UploadDate', 'Title', 'Thumbnails', 'Description', 'Categories', 'Tags',
       'Duration', 'ViewCount', 'LikeCount', 'DislikeCount', 'AverageRating']

dfRaw2 = dfRaw2[columns]

# %% [markdown]
# ## Extracting information from the original columns

# %%
#Categories
dfRaw2['Categories'] = dfRaw2['Categories'].apply(lambda row: row.strip("'[").strip("']"))
#Tags
dfRaw2['Tags'] = dfRaw2['Tags'].apply(lambda row: str(row).strip("[").strip("]").replace("'",''))

#Thumbanil URL
def GetThumbnail(text):
    pattern = "http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"
    urlThumbnail = re.search(pattern, text).group(0).rstrip("'")
    return urlThumbnail

dfRaw2['ThumbnailUrl'] = dfRaw2['Thumbnails'].apply(lambda row: GetThumbnail(str(row).strip('"[').strip(']"').split(',')[0]))

# Thumbnail Width and Height
def GetValue(text):
    pattern = "(\d+)"
    value = int(re.search(pattern, text).group(0))
    return value

# Thumbnail Width
dfRaw2['ThumbnailWidth'] = dfRaw2['Thumbnails'].apply(lambda row: GetValue(str(row).strip('"[').strip(']"').split(',')[1]))
# Thumbnail Height
dfRaw2['ThumbnailHeight'] = dfRaw2['Thumbnails'].apply(lambda row: GetValue(str(row).strip('"[').strip(']"').split(',')[2]))

# %% [markdown]
# ### Drop columns irrelevant

# %%
dfRaw2 = dfRaw2.drop('Thumbnails', axis=1)

# %% [markdown]
# # Convert to .feather

# %%
dfRaw2.to_feather('../Data/FeatherData/YouTubeStackExchangeQueryRaw.feather')
