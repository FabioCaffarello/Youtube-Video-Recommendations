# %% [markdown]
# # IMPORTS

# %% [markdown]
# ## Libraries

# %%
import warnings

import pandas as pd
import numpy  as np
import joblib as jb

import matplotlib.pyplot as plt

from skopt                           import forest_minimize
from lightgbm                        import LGBMClassifier
from scipy.sparse                    import hstack, csr_matrix
from sklearn.metrics                 import roc_auc_score, average_precision_score
from sklearn.ensemble                import RandomForestClassifier
from sklearn.linear_model            import LogisticRegression
from sklearn.preprocessing           import MaxAbsScaler
from sklearn.feature_extraction.text import TfidfVectorizer


np.random.seed(0)
# %matplotlib inline
pd.set_option('display.max_columns', 200)
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Data

# %%
dfGS = pd.read_feather('../Data/FeatherData/dfAllDataLabeled.feather')
dfStack = pd.read_csv('../Data/StackTags/dfTags.csv')
for col in dfStack.columns:
    dfStack = dfStack.rename(columns={col: col + "Stack"})

# %%
dfRaw = pd.merge(dfGS, dfStack, how='left', left_on='Query', right_on='TagStack')
dfRaw = dfRaw.sort_values('UploadDate')

# %%
dfRaw.head()
# Out:
#       WatchList           Id                           Uploader UploadDate  \
# 0             0  fFPsjpP5Shs                             PyData 2014-04-03
# 1473          0  Y7avOZl97ls                           edureka! 2014-09-05
# 1             1  luecsqQ636c                    Montreal-Python 2014-11-20
# 2             0  3XCatMUuGDo  ESAC Data Analysis and Statistics 2014-12-05
# 3             1  KTeVOb8gaD4                            sentdex 2014-12-22
#
#                                                   Title  \
# 0     Linda Uruchurtu: A Beginner's Guide to Random ...
# 1473  Random Forest Classifier | Data Science | Edureka
# 1     Automating microscopy data analysis using Djan...
# 2     Jake VanderPlas: Bayesian model validation and...
# 3     Scikit Learn Machine Learning SVM Tutorial wit...
#
#                                             Description            Categories  \
# 0               Linda Uruchurtu: A Beginner's Guide to         People & Blogs
# 1473  Data Science Training - https://www.edureka.co...             Education
# 1     Montreal, Oct. 20, 2014 - Eleyine Zarour demon...  Science & Technology
# 2     Tutorial by Jake VanderPlas at the ESAC Data A...        People & Blogs
# 3     In this machine learning tutorial, we cover a ...             Education
#
#                                                    Tags  Duration  ViewCount  \
# 0     Python (Software), Random Forest, R (Programmi...      2277         38
# 1473                                               None       711          8
# 1     montreal, python, technology, dev, code, confe...      1047          3
# 2     ESAC, Data Analysis (Media Genre), Statistics ...      1254          1
# 3     Scikit-learn, Python (Programming Language), M...      1427        303
#
#       LikeCount  DislikeCount  AverageRating             Query  \
# 0           266            54       4.325000     random-forest
# 1473          8            10       2.777778     random-forest
# 1            52             3       4.781818             scipy
# 2             6             2       4.428571  cross-validation
# 3          2303            72       4.878737               svm
#
#       DaysSincePublication                                       ThumbnailUrl  \
# 0                     2465  https://i.ytimg.com/vi/fFPsjpP5Shs/hqdefault.j...
# 1473                  2310  https://i.ytimg.com/vi/Y7avOZl97ls/hqdefault.j...
# 1                     2234  https://i.ytimg.com/vi/luecsqQ636c/hqdefault.j...
# 2                     2219  https://i.ytimg.com/vi/3XCatMUuGDo/hqdefault.j...
# 3                     2202  https://i.ytimg.com/vi/KTeVOb8gaD4/hqdefault.j...
#
#      ThumbnailWidth ThumbnailHeight  \
# 0               168              94
# 1473            168              94
# 1               168              94
# 2               168              94
# 3               168              94
#
#                                                   Tags   New  \
# 0                                                  None  0.0
# 1473  Data Science, R Programming, random forest in ...  1.0
# 1                                                  None  0.0
# 2                                                  None  0.0
# 3                                                  None  0.0
#
#               TagStack  IncidenceStack  VotesStack  AnswerStack  ViewsStack  \
# 0        random-forest            99.0       281.0        100.0    282108.0
# 1473     random-forest            99.0       281.0        100.0    282108.0
# 1                scipy            96.0       201.0         99.0    235177.0
# 2     cross-validation            59.0       235.0         65.0    241737.0
# 3                  svm            71.0       234.0         86.0    372999.0
#
#       ViewsPerIncidenceStack
# 0                2849.575758
# 1473             2849.575758
# 1                2449.760417
# 2                4097.237288
# 3                5253.507042

# %% [markdown]
# # Feature Engineering

# %%
dfRaw.shape
# Out:
# (1773, 26)

# %%
dfFeatures = pd.DataFrame(index=dfRaw.index)
#dfFeatures['ViewCount'] = dfRaw['ViewCount']
#dfFeatures['DaysSincePublication'] = dfRaw['DaysSincePublication']
dfFeatures['WatchList'] = dfRaw['WatchList']
dfFeatures['ViewsPerDay'] = dfRaw['ViewCount'] / dfRaw['DaysSincePublication']
#dfFeatures = dfFeatures.drop('DaysSincePublication', axis=1)


dfFeatures['Duration'] = dfRaw['Duration']
## Stack

dfFeatures['ViewCountIncidenceStack'] = dfRaw['ViewCount'] / dfRaw['IncidenceStack']
dfFeatures['ViewCountIncidenceStack'].fillna(dfFeatures['ViewCountIncidenceStack'].mean(), inplace=True)

dfFeatures['VotesStackLikeCount'] = dfRaw['VotesStack'] * dfRaw['LikeCount']
dfFeatures['VotesStackLikeCount'].fillna(dfFeatures['VotesStackLikeCount'].mean(), inplace=True)

# %% [markdown]
# # Split DataFrame into Training and Validation Dataset

# %%
dfRaw['UploadDate'].iloc[int(round(dfRaw.shape[0]/2,0))]
# Out:
# Timestamp('2019-11-27 00:00:00')

# %%
dateSplit = '2019-11-27'

maskTrain = (dfRaw['UploadDate'] < dateSplit)

maskVal = (dfRaw['UploadDate'] >= dateSplit)

Xtrain, Xval = dfFeatures[maskTrain].drop('WatchList', axis=1) , dfFeatures[maskVal].drop('WatchList', axis=1)
ytrain, yval = dfFeatures[maskTrain]['WatchList'], dfFeatures[maskVal]['WatchList']

titleTrain = dfRaw[maskTrain]['Title']
titleVal = dfRaw[maskVal]['Title']

# %%
Xtrain.shape, Xval.shape, ytrain.shape, yval.shape
# Out:
# ((885, 4), (888, 4), (885,), (888,))

# %% [markdown]
# # Model

# %% [markdown]
# ## RandomForestClassifier

# %% [markdown]
# ### Bayesian Optimization

# %%
def tuneRf(params):
    print(params)
    max_depth = params[0]
    min_samples_leaf = params[1]
    n_estimators = params[2]
    min_df = params[3]
    ngram_range = (1, params[4])
    
    titleVec = TfidfVectorizer(min_df=min_df, ngram_range=ngram_range)
    titleBowTrain = titleVec.fit_transform(titleTrain)
    titleBowVal = titleVec.transform(titleVal)
    
    XtrainWTitle = hstack([Xtrain, titleBowTrain])
    XvalWTitle = hstack([Xval, titleBowVal])
    
    model = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_leaf=min_samples_leaf, random_state=0,
                                   class_weight='balanced', n_jobs=-1)
    
    model.fit(XtrainWTitle, ytrain)
    
    p = model.predict_proba(XvalWTitle)[:,1]
    
    print(roc_auc_score(yval, p))
    
    return -average_precision_score(yval,p)



space = [(1, 10), #max_depth
        (1, 20), #min_samples_leaf 
        (100, 1000), #n_estimetors
        (1, 5), #min_df
        (1, 5)] #ngram_range



result = forest_minimize(tuneRf, space, random_state=160745, n_random_starts=20, n_calls=50, verbose=1)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [5, 16, 771, 1, 3]
# 0.8350704380365397
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 1.1595
# Function value obtained: -0.4903
# Current minimum: -0.4903
# Iteration No: 2 started. Evaluating function at random point.
# [8, 9, 272, 3, 1]
# 0.8699537750385209
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.4060
# Function value obtained: -0.5348
# Current minimum: -0.5348
# Iteration No: 3 started. Evaluating function at random point.
# [2, 10, 804, 3, 4]
# 0.847672243011226
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 1.1952
# Function value obtained: -0.5014
# Current minimum: -0.5348
# Iteration No: 4 started. Evaluating function at random point.
# [6, 2, 110, 4, 5]
# 0.8639500330178297
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.2321
# Function value obtained: -0.5256
# Current minimum: -0.5348
# Iteration No: 5 started. Evaluating function at random point.
# [6, 20, 783, 1, 4]
# 0.8146213955535989
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 1.1214
# Function value obtained: -0.4765
# Current minimum: -0.5348
# Iteration No: 6 started. Evaluating function at random point.
# [9, 9, 605, 1, 2]
# 0.8463075060532688
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.8551
# Function value obtained: -0.4951
# Current minimum: -0.5348
# Iteration No: 7 started. Evaluating function at random point.
# [10, 13, 493, 1, 3]
# 0.8292703059652212
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.7274
# Function value obtained: -0.4785
# Current minimum: -0.5348
# Iteration No: 8 started. Evaluating function at random point.
# [5, 12, 753, 1, 5]
# 0.7726887519260401
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 1.1366
# Function value obtained: -0.3968
# Current minimum: -0.5348
# Iteration No: 9 started. Evaluating function at random point.
# [10, 19, 588, 2, 5]
# 0.8486902927580894
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.8903
# Function value obtained: -0.5173
# Current minimum: -0.5348
# Iteration No: 10 started. Evaluating function at random point.
# [5, 8, 406, 5, 3]
# 0.8749779881135813
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.6177
# Function value obtained: -0.5324
# Current minimum: -0.5348
# Iteration No: 11 started. Evaluating function at random point.
# [10, 1, 803, 1, 2]
# 0.8545894783182919
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 1.1905
# Function value obtained: -0.5162
# Current minimum: -0.5348
# Iteration No: 12 started. Evaluating function at random point.
# [1, 8, 529, 3, 4]
# 0.8539456306405458
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.7744
# Function value obtained: -0.5167
# Current minimum: -0.5348
# Iteration No: 13 started. Evaluating function at random point.
# [8, 19, 189, 5, 3]
# 0.865166189742461
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.3184
# Function value obtained: -0.5255
# Current minimum: -0.5348
# Iteration No: 14 started. Evaluating function at random point.
# [6, 18, 374, 4, 1]
# 0.8732005282852741
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.5501
# Function value obtained: -0.5655
# Current minimum: -0.5655
# Iteration No: 15 started. Evaluating function at random point.
# [7, 8, 871, 5, 3]
# 0.8724191063174114
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 1.2922
# Function value obtained: -0.5292
# Current minimum: -0.5655
# Iteration No: 16 started. Evaluating function at random point.
# [3, 2, 449, 5, 2]
# 0.8711149020471052
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.6968
# Function value obtained: -0.5176
# Current minimum: -0.5655
# Iteration No: 17 started. Evaluating function at random point.
# [2, 14, 138, 5, 3]
# 0.8547050407219898
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.2657
# Function value obtained: -0.5120
# Current minimum: -0.5655
# Iteration No: 18 started. Evaluating function at random point.
# [1, 9, 487, 4, 5]
# 0.8548866387849438
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.7509
# Function value obtained: -0.4960
# Current minimum: -0.5655
# Iteration No: 19 started. Evaluating function at random point.
# [6, 9, 577, 5, 2]
# 0.8700858463570328
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.8696
# Function value obtained: -0.5273
# Current minimum: -0.5655
# Iteration No: 20 started. Evaluating function at random point.
# [10, 5, 523, 3, 5]
# 0.8669271406559542
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 1.1115
# Function value obtained: -0.5181
# Current minimum: -0.5655
# Iteration No: 21 started. Searching for the next optimal point.
# [5, 20, 381, 2, 1]
# 0.8592119744662118
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.7421
# Function value obtained: -0.5357
# Current minimum: -0.5655
# Iteration No: 22 started. Searching for the next optimal point.
# [5, 10, 765, 2, 1]
# 0.8549416685009904
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 1.2834
# Function value obtained: -0.5017
# Current minimum: -0.5655
# Iteration No: 23 started. Searching for the next optimal point.
# [5, 19, 344, 1, 1]
# 0.8552663438256659
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.6912
# Function value obtained: -0.5177
# Current minimum: -0.5655
# Iteration No: 24 started. Searching for the next optimal point.
# [6, 18, 398, 2, 5]
# 0.8515628439357253
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.7789
# Function value obtained: -0.5273
# Current minimum: -0.5655
# Iteration No: 25 started. Searching for the next optimal point.
# [5, 18, 774, 4, 1]
# 0.8711534228483381
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 1.2746
# Function value obtained: -0.5613
# Current minimum: -0.5655
# Iteration No: 26 started. Searching for the next optimal point.
# [6, 18, 993, 3, 1]
# 0.8702179176755447
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 1.5436
# Function value obtained: -0.5503
# Current minimum: -0.5655
# Iteration No: 27 started. Searching for the next optimal point.
# [6, 18, 765, 4, 4]
# 0.864571868809157
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 1.3205
# Function value obtained: -0.5360
# Current minimum: -0.5655
# Iteration No: 28 started. Searching for the next optimal point.
# [6, 18, 885, 1, 1]
# 0.8451683909311027
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 1.3855
# Function value obtained: -0.4995
# Current minimum: -0.5655
# Iteration No: 29 started. Searching for the next optimal point.
# [5, 17, 807, 4, 1]
# 0.8707682148360114
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 1.3106
# Function value obtained: -0.5604
# Current minimum: -0.5655
# Iteration No: 30 started. Searching for the next optimal point.
# [1, 18, 701, 4, 1]
# 0.8634437596302004
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 1.2116
# Function value obtained: -0.5461
# Current minimum: -0.5655
# Iteration No: 31 started. Searching for the next optimal point.
# [2, 16, 768, 4, 1]
# 0.8606317411402158
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 1.3641
# Function value obtained: -0.5281
# Current minimum: -0.5655
# Iteration No: 32 started. Searching for the next optimal point.
# [5, 13, 952, 4, 1]
# 0.8688861985472155
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 1.5234
# Function value obtained: -0.5359
# Current minimum: -0.5655
# Iteration No: 33 started. Searching for the next optimal point.
# [5, 20, 985, 3, 1]
# 0.8685450143077261
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 1.5313
# Function value obtained: -0.5492
# Current minimum: -0.5655
# Iteration No: 34 started. Searching for the next optimal point.
# [6, 18, 894, 2, 5]
# 0.8478978648470175
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 1.4741
# Function value obtained: -0.5121
# Current minimum: -0.5655
# Iteration No: 35 started. Searching for the next optimal point.
# [1, 18, 219, 4, 1]
# 0.8477437816420869
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.5080
# Function value obtained: -0.5218
# Current minimum: -0.5655
# Iteration No: 36 started. Searching for the next optimal point.
# [9, 20, 188, 4, 1]
# 0.8630310367598504
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.4837
# Function value obtained: -0.5479
# Current minimum: -0.5655
# Iteration No: 37 started. Searching for the next optimal point.
# [5, 18, 363, 4, 1]
# 0.8723640766013647
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.7074
# Function value obtained: -0.5642
# Current minimum: -0.5655
# Iteration No: 38 started. Searching for the next optimal point.
# [5, 18, 106, 5, 1]
# 0.8652652432313448
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.3771
# Function value obtained: -0.5487
# Current minimum: -0.5655
# Iteration No: 39 started. Searching for the next optimal point.
# [5, 15, 434, 4, 1]
# 0.8698877393792647
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.9024
# Function value obtained: -0.5558
# Current minimum: -0.5655
# Iteration No: 40 started. Searching for the next optimal point.
# [4, 19, 457, 4, 1]
# 0.8694805194805195
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.8397
# Function value obtained: -0.5606
# Current minimum: -0.5655
# Iteration No: 41 started. Searching for the next optimal point.
# [3, 18, 457, 4, 1]
# 0.8651441778560424
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.8529
# Function value obtained: -0.5474
# Current minimum: -0.5655
# Iteration No: 42 started. Searching for the next optimal point.
# [10, 18, 363, 5, 1]
# 0.8697666740039622
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.7398
# Function value obtained: -0.5618
# Current minimum: -0.5655
# Iteration No: 43 started. Searching for the next optimal point.
# [9, 17, 386, 5, 1]
# 0.8714946070878274
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.7394
# Function value obtained: -0.5594
# Current minimum: -0.5655
# Iteration No: 44 started. Searching for the next optimal point.
# [5, 10, 364, 4, 1]
# 0.8662227602905569
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.7088
# Function value obtained: -0.5343
# Current minimum: -0.5655
# Iteration No: 45 started. Searching for the next optimal point.
# [6, 17, 376, 3, 1]
# 0.8724191063174115
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.7147
# Function value obtained: -0.5510
# Current minimum: -0.5655
# Iteration No: 46 started. Searching for the next optimal point.
# [5, 18, 488, 4, 2]
# 0.875544794188862
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.9174
# Function value obtained: -0.5685
# Current minimum: -0.5685
# Iteration No: 47 started. Searching for the next optimal point.
# [6, 18, 346, 4, 2]
# 0.872209993396434
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.7037
# Function value obtained: -0.5540
# Current minimum: -0.5685
# Iteration No: 48 started. Searching for the next optimal point.
# [5, 17, 479, 4, 2]
# 0.8741250275148581
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.8803
# Function value obtained: -0.5632
# Current minimum: -0.5685
# Iteration No: 49 started. Searching for the next optimal point.
# [5, 17, 581, 3, 2]
# 0.8708892802113141
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 1.0457
# Function value obtained: -0.5472
# Current minimum: -0.5685
# Iteration No: 50 started. Searching for the next optimal point.
# [4, 17, 373, 4, 3]
# 0.8650176095091348
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.7416
# Function value obtained: -0.5187
# Current minimum: -0.5685

# %%
result.x
# Out:
# [5, 18, 488, 4, 2]

# %% [markdown]
# ##### RandomForestClassifier
#
# - [5, 18, 488, 4, 2]
# - ap: 0.5685, auc: 0.875544794188862

# %% [markdown]
# ### Model With Hyperparameter Tuning

# %%
params = [5, #max_depth
 18, #min_samples_leaf 
 489, #n_estimetors
 4,#min_df
 2] #ngram_range


max_depth = params[0]
min_samples_leaf = params[1]
n_estimators = params[2]
min_df = params[3]
ngram_range = (1, params[4])


titleVec = TfidfVectorizer(min_df=min_df, ngram_range=ngram_range)
titleBowTrain = titleVec.fit_transform(titleTrain)
titleBowVal = titleVec.transform(titleVal)

XtrainWTitle = hstack([Xtrain, titleBowTrain])
XvalWTitle = hstack([Xval, titleBowVal])

modelRf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, min_samples_leaf=min_samples_leaf, random_state=0,
                               class_weight='balanced', n_jobs=-1)

modelRf.fit(XtrainWTitle, ytrain)

pRf = modelRf.predict_proba(XvalWTitle)[:,1]
#ap: 0.5686275377746386, auc: 0.8754897644728153
print(f'ap: {average_precision_score(yval,pRf)}, auc: {roc_auc_score(yval, pRf)}')
# Out:
# ap: 0.5686275377746386, auc: 0.8754897644728153

# %% [markdown]
# ## LGBMClassifier

# %% [markdown]
# ### Bayesian Optimization

# %%
def tuneLGBM(params):
    print(params)
    lr = params[0]
    max_depth = params[1]
    min_child_samples = params[2]
    subsample = params[3]
    colsample_bytree = params[4]
    n_estimators = params[5]
    min_df = params[6]
    ngram_range = (1, params[7])
    
    titleVec = TfidfVectorizer(min_df=min_df, ngram_range=ngram_range)
    titleBowTrain = titleVec.fit_transform(titleTrain)
    titleBowVal = titleVec.transform(titleVal)
    
    XtrainWTitle = hstack([Xtrain, titleBowTrain])
    XvalWTitle = hstack([Xval, titleBowVal])
    
    model = LGBMClassifier(learning_rate=lr, num_leaves=2 ** max_depth, max_depth=max_depth,
                           min_child_samples=min_child_samples, subsample=subsample, colsample_bytree=colsample_bytree,
                           bagging_freq=1, n_estimators=n_estimators, random_state=0, class_weight='balanced', n_jobs=-1)
    
    model.fit(XtrainWTitle, ytrain)
    
    p = model.predict_proba(XvalWTitle)[:,1]
    
    print(roc_auc_score(yval, p))
    
    return -average_precision_score(yval,p)



space = [(1e-3, 1e-1, 'log-uniform'), #lr
        (1, 10), #max_depth
        (1, 20), #min_child_samples
        (0.05, 1.0), #subsample
        (0.05, 1.0), #colsample_bytree
        (100, 1000), #n_estimetors
        (1, 5), #min_df
        (1, 5)] #ngram_range



result = forest_minimize(tuneLGBM, space, random_state=160745, n_random_starts=20, n_calls=50, verbose=1)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# [0.009944912110647982, 5, 1, 0.4677107511929402, 0.49263223036174764, 272, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8823464670922297
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.6432
# Function value obtained: -0.5671
# Current minimum: -0.5671
# Iteration No: 2 started. Evaluating function at random point.
# [0.053887464791860025, 1, 15, 0.7437489153990157, 0.8675167974293533, 549, 3, 4]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8611160026414264
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.2490
# Function value obtained: -0.4711
# Current minimum: -0.5671
# Iteration No: 3 started. Evaluating function at random point.
# [0.004151454520895999, 6, 20, 0.8682075103820793, 0.9491436163200662, 411, 4, 3]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8647589698437156
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.4877
# Function value obtained: -0.5239
# Current minimum: -0.5671
# Iteration No: 4 started. Evaluating function at random point.
# [0.0014099928811969545, 9, 9, 0.6502182010234373, 0.6866210554187129, 828, 5, 2]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8678516398855383
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 1.6037
# Function value obtained: -0.5317
# Current minimum: -0.5671
# Iteration No: 5 started. Evaluating function at random point.
# [0.08530558241838007, 8, 19, 0.2137736299768322, 0.1313765544201984, 961, 4, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.7619854721549637
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.6119
# Function value obtained: -0.3274
# Current minimum: -0.5671
# Iteration No: 6 started. Evaluating function at random point.
# [0.003567949451535685, 10, 19, 0.7232951768944309, 0.7298538828427115, 939, 4, 3]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8603896103896104
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 1.4707
# Function value obtained: -0.5116
# Current minimum: -0.5671
# Iteration No: 7 started. Evaluating function at random point.
# [0.014828577273549474, 7, 1, 0.18428087097824575, 0.3261556557915816, 274, 1, 2]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8630970724191063
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 2.0332
# Function value obtained: -0.4787
# Current minimum: -0.5671
# Iteration No: 8 started. Evaluating function at random point.
# [0.0015212976972079912, 3, 12, 0.44234694306528044, 0.399351303640462, 272, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.87557781201849
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.4349
# Function value obtained: -0.5731
# Current minimum: -0.5731
# Iteration No: 9 started. Evaluating function at random point.
# [0.01946212855369041, 9, 18, 0.5235636153223084, 0.6728679300083596, 747, 4, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8365287255117763
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 1.0084
# Function value obtained: -0.4551
# Current minimum: -0.5731
# Iteration No: 10 started. Evaluating function at random point.
# [0.0012116790683302117, 3, 2, 0.06616307483844217, 0.23025600705315752, 677, 2, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8625797930882676
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 1.7789
# Function value obtained: -0.5523
# Current minimum: -0.5731
# Iteration No: 11 started. Evaluating function at random point.
# [0.0053139776214487944, 6, 9, 0.14251441334450304, 0.8175761405215897, 297, 1, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8439357252916575
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.5860
# Function value obtained: -0.4882
# Current minimum: -0.5731
# Iteration No: 12 started. Evaluating function at random point.
# [0.0068572961982704935, 10, 5, 0.2390386584472456, 0.49053406102209746, 176, 2, 4]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8565045124367158
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 0.7784
# Function value obtained: -0.5193
# Current minimum: -0.5731
# Iteration No: 13 started. Evaluating function at random point.
# [0.00781968225875022, 3, 4, 0.7078936710077383, 0.31818755505678337, 275, 4, 4]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8745597622716268
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.3782
# Function value obtained: -0.5367
# Current minimum: -0.5731
# Iteration No: 14 started. Evaluating function at random point.
# [0.017293945600511968, 2, 15, 0.9007557574888567, 0.41026441194439994, 316, 5, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8713240149680826
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.2039
# Function value obtained: -0.5340
# Current minimum: -0.5731
# Iteration No: 15 started. Evaluating function at random point.
# [0.012250750764764855, 8, 6, 0.5976582413192033, 0.2474882432951916, 516, 4, 4]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8466431873211534
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.9068
# Function value obtained: -0.5017
# Current minimum: -0.5731
# Iteration No: 16 started. Evaluating function at random point.
# [0.018353598126553926, 4, 3, 0.47305622526323254, 0.1404164811277527, 133, 4, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8421802773497689
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.2828
# Function value obtained: -0.4869
# Current minimum: -0.5731
# Iteration No: 17 started. Evaluating function at random point.
# [0.0010383234748454694, 9, 19, 0.9256771571832196, 0.9321438677645206, 312, 4, 3]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8401716927140656
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.7467
# Function value obtained: -0.4877
# Current minimum: -0.5731
# Iteration No: 18 started. Evaluating function at random point.
# [0.004955229758078229, 5, 5, 0.06939551310802591, 0.4193273080472823, 725, 4, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8368038740920096
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 0.6782
# Function value obtained: -0.5037
# Current minimum: -0.5731
# Iteration No: 19 started. Evaluating function at random point.
# [0.0699516121742407, 9, 10, 0.6477856515609233, 0.8594430701440198, 616, 1, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8414924058991855
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 1.0088
# Function value obtained: -0.4161
# Current minimum: -0.5731
# Iteration No: 20 started. Evaluating function at random point.
# [0.0014752743467850462, 5, 4, 0.9747950537021096, 0.982207187458162, 909, 2, 4]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8522727272727273
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 1.5719
# Function value obtained: -0.4860
# Current minimum: -0.5731
# Iteration No: 21 started. Searching for the next optimal point.
# [0.031689067396661816, 3, 2, 0.5067746419648725, 0.10619791974693481, 246, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8666960158485582
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.5799
# Function value obtained: -0.5230
# Current minimum: -0.5731
# Iteration No: 22 started. Searching for the next optimal point.
# [0.0014590657064127333, 3, 11, 0.7690274316989901, 0.13604822392302804, 204, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8707076821483601
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.4572
# Function value obtained: -0.5348
# Current minimum: -0.5731
# Iteration No: 23 started. Searching for the next optimal point.
# [0.0017006175984719564, 1, 18, 0.3845370558636049, 0.46748967673726044, 831, 2, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.854325335681268
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.7130
# Function value obtained: -0.5108
# Current minimum: -0.5731
# Iteration No: 24 started. Searching for the next optimal point.
# [0.060356955153737096, 3, 14, 0.4572749701479573, 0.5003656657414612, 339, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8390380805635043
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.6879
# Function value obtained: -0.4451
# Current minimum: -0.5731
# Iteration No: 25 started. Searching for the next optimal point.
# [0.009555444369946606, 6, 8, 0.45990414391816153, 0.11649503767204109, 866, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8041712524763371
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 1.2972
# Function value obtained: -0.4130
# Current minimum: -0.5731
# Iteration No: 26 started. Searching for the next optimal point.
# [0.0019574441931429227, 2, 7, 0.11075388234583461, 0.11688508423102786, 956, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8707241910631741
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 1.2628
# Function value obtained: -0.5547
# Current minimum: -0.5731
# Iteration No: 27 started. Searching for the next optimal point.
# [0.008853211416106163, 3, 10, 0.16811574803220247, 0.32624503398026244, 707, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8620515078142198
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 1.0092
# Function value obtained: -0.5330
# Current minimum: -0.5731
# Iteration No: 28 started. Searching for the next optimal point.
# [0.0017434676825835804, 6, 17, 0.6860671162589904, 0.2893350368104667, 294, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8651771956856702
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.5503
# Function value obtained: -0.5272
# Current minimum: -0.5731
# Iteration No: 29 started. Searching for the next optimal point.
# [0.01403825395740692, 1, 7, 0.1440622689540107, 0.25550076392006266, 664, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8742020691173235
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.6875
# Function value obtained: -0.5648
# Current minimum: -0.5731
# Iteration No: 30 started. Searching for the next optimal point.
# [0.04140117322325939, 1, 12, 0.10680540546023973, 0.149513556345917, 938, 4, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8214725952014088
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.6888
# Function value obtained: -0.4946
# Current minimum: -0.5731
# Iteration No: 31 started. Searching for the next optimal point.
# [0.030653016198790246, 5, 1, 0.1534608692516908, 0.15874728061924007, 459, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8316530926700417
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.9544
# Function value obtained: -0.4743
# Current minimum: -0.5731
# Iteration No: 32 started. Searching for the next optimal point.
# [0.01363909505250592, 1, 2, 0.20529585026077568, 0.4083756377635872, 949, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8668170812238609
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 2.4083
# Function value obtained: -0.5404
# Current minimum: -0.5731
# Iteration No: 33 started. Searching for the next optimal point.
# [0.01240076292888934, 2, 10, 0.23837981988503004, 0.1378613551178544, 956, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8829958177415805
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.8827
# Function value obtained: -0.5584
# Current minimum: -0.5731
# Iteration No: 34 started. Searching for the next optimal point.
# [0.012234957862904586, 3, 20, 0.2503168214030468, 0.26095720870423555, 535, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8551948051948051
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.6071
# Function value obtained: -0.5443
# Current minimum: -0.5731
# Iteration No: 35 started. Searching for the next optimal point.
# [0.013112427311291376, 4, 20, 0.2654154483195213, 0.7759340370071708, 792, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8281091789566366
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.7569
# Function value obtained: -0.4813
# Current minimum: -0.5731
# Iteration No: 36 started. Searching for the next optimal point.
# [0.0020723545019716866, 5, 10, 0.17020338193777657, 0.07313694875187762, 935, 5, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.841239269205371
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 1.2153
# Function value obtained: -0.5051
# Current minimum: -0.5731
# Iteration No: 37 started. Searching for the next optimal point.
# [0.0021264575885157726, 3, 12, 0.4545386688759975, 0.06443227161576885, 245, 1, 3]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8436055469953775
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.6149
# Function value obtained: -0.4968
# Current minimum: -0.5731
# Iteration No: 38 started. Searching for the next optimal point.
# [0.0940013577370778, 1, 2, 0.21436085413302536, 0.41891946211841014, 989, 2, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8399295619634602
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 1.6686
# Function value obtained: -0.3893
# Current minimum: -0.5731
# Iteration No: 39 started. Searching for the next optimal point.
# [0.013902438556035242, 1, 6, 0.49181045659024186, 0.1862248052956837, 922, 2, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8739159145938806
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 1.1698
# Function value obtained: -0.5090
# Current minimum: -0.5731
# Iteration No: 40 started. Searching for the next optimal point.
# [0.01226914549812457, 7, 16, 0.9318149910872408, 0.3914512651807273, 123, 5, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8635593220338984
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.4498
# Function value obtained: -0.5520
# Current minimum: -0.5731
# Iteration No: 41 started. Searching for the next optimal point.
# [0.012028980052817556, 10, 15, 0.774954136904049, 0.1610132192621926, 184, 4, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8185340083645168
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.5739
# Function value obtained: -0.4666
# Current minimum: -0.5731
# Iteration No: 42 started. Searching for the next optimal point.
# [0.010663280879077463, 7, 19, 0.932237162663776, 0.4968835854333092, 884, 4, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8507484041382347
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 1.0726
# Function value obtained: -0.4728
# Current minimum: -0.5731
# Iteration No: 43 started. Searching for the next optimal point.
# [0.017894760472517108, 1, 1, 0.21221132860493563, 0.3422962948396006, 777, 2, 3]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8720008804754568
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 2.1064
# Function value obtained: -0.5100
# Current minimum: -0.5731
# Iteration No: 44 started. Searching for the next optimal point.
# [0.024311319305844407, 2, 3, 0.2579464549853159, 0.1178051824657122, 867, 5, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8621395553598944
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 1.0631
# Function value obtained: -0.4899
# Current minimum: -0.5731
# Iteration No: 45 started. Searching for the next optimal point.
# [0.016211107152425557, 8, 10, 0.829640895941524, 0.4829684928073689, 230, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8659586176535329
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.6609
# Function value obtained: -0.5392
# Current minimum: -0.5731
# Iteration No: 46 started. Searching for the next optimal point.
# [0.01714830983479785, 1, 8, 0.2158187064544344, 0.403074532646948, 966, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8813119084305524
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.8847
# Function value obtained: -0.5666
# Current minimum: -0.5731
# Iteration No: 47 started. Searching for the next optimal point.
# [0.020349099451124432, 1, 18, 0.27673827661145683, 0.4467606029555766, 936, 3, 5]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8558661677305746
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.8909
# Function value obtained: -0.5025
# Current minimum: -0.5731
# Iteration No: 48 started. Searching for the next optimal point.
# [0.015437923720614009, 1, 20, 0.13916018131745939, 0.31587457226937726, 857, 4, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8198987453224742
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.6131
# Function value obtained: -0.4750
# Current minimum: -0.5731
# Iteration No: 49 started. Searching for the next optimal point.
# [0.009065510153278191, 4, 4, 0.10503193238909733, 0.35437438061036025, 960, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8712744882236407
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 1.2050
# Function value obtained: -0.5337
# Current minimum: -0.5731
# Iteration No: 50 started. Searching for the next optimal point.
# [0.016882649860253035, 8, 7, 0.3680102364206412, 0.40770508909128395, 583, 3, 1]
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# 0.8671582654633502
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 1.2628
# Function value obtained: -0.4877
# Current minimum: -0.5731

# %%
result.x
# Out:
# [0.0015212976972079912,
#  3,
#  12,
#  0.44234694306528044,
#  0.399351303640462,
#  272,
#  3,
#  5]

# %% [markdown]
# ##### LGBMClassifier
#
# - [0.0015212976972079912, 3, 12, 0.44234694306528044, 0.399351303640462, 272, 3, 5]
# - ap: 0.5731, auc: 0.87557781201849

# %% [markdown]
# ## Model With Hyperparameter Tuning

# %%
params = [0.0015212976972079912, #lr
 3, #max_depth
 17, #min_child_samples
 0.44234694306528044, #subsample
 0.399351303640462, #colsample_bytree
 881, #n_estimetors
 4,  #min_df
 2] #ngram_range


lr = params[0]
max_depth = params[1]
min_child_samples = params[2]
subsample = params[3]
colsample_bytree = params[4]
n_estimators = params[5]
min_df = params[6]
ngram_range = (1, params[7])

titleVec = TfidfVectorizer(min_df=min_df, ngram_range=ngram_range)
titleBowTrain = titleVec.fit_transform(titleTrain)
titleBowVal = titleVec.transform(titleVal)

XtrainWTitle = hstack([Xtrain, titleBowTrain])
XvalWTitle = hstack([Xval, titleBowVal])

modelLgbm = LGBMClassifier(learning_rate=lr, num_leaves=2 ** max_depth, max_depth=max_depth,
                       min_child_samples=min_child_samples, subsample=subsample, colsample_bytree=colsample_bytree,
                       bagging_freq=1, n_estimators=n_estimators, random_state=0, class_weight='balanced', n_jobs=-1)

modelLgbm.fit(XtrainWTitle, ytrain)

pLgbm = modelLgbm.predict_proba(XvalWTitle)[:,1]


print(f'ap: {average_precision_score(yval,pLgbm)}, auc: {roc_auc_score(yval, pLgbm)}')
# Out:
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# ap: 0.5752235771400988, auc: 0.8819282412502751

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# # Ensamble

# %% [markdown]
# - LGBM | ap: 0.5752235771400988, auc: 0.8819282412502751
# - RF   | ap: 0.5686275377746386, auc: 0.8754897644728153

# %%
pd.DataFrame({'RF': pRf, 'LGBM': pLgbm}).corr()
# Out:
#             RF      LGBM
# RF    1.000000  0.923365
# LGBM  0.923365  1.000000

# %%
p = (0.5*pRf + 0.5*pLgbm)
print(f'ap: {average_precision_score(yval,p)}, auc: {roc_auc_score(yval, p)}')
# Out:
# ap: 0.5884758482319418, auc: 0.8839423288575831

# %% [markdown]
# # Save Model

# %%
jb.dump(modelRf,'D:/01-DataScience/04-Projetos/00-Git/Youtube-Video-Recommendations/Model/modelRf.pkl.z')
jb.dump(modelLgbm,'D:/01-DataScience/04-Projetos/00-Git/Youtube-Video-Recommendations/Model/modelLgbm.pkl.z')
jb.dump(titleVec,'D:/01-DataScience/04-Projetos/00-Git/Youtube-Video-Recommendations/Parameter/titleVec.pkl.z')
# Out:
# ['D:/01-DataScience/04-Projetos/00-Git/Youtube-Video-Recommendations/Parameter/titleVec.pkl.z']
