# %% [markdown]
# # Imports

# %% [markdown]
# ## Libraries

# %%
import youtube_dlc # pip install youtube-dlc
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 200)

# %%
ydl = youtube_dlc.YoutubeDL({'ignoreerrors':True})

# %%
array_querry = ['machine-learning',
 'scikit-learn',
 'regression',
 'time-series',
 'neural-networks',
 'classification',
 'statsmodels',
 'random-forest',
 'scipy',
 'logistic',
 'data-visualization',
 'distributions',
 'bayesian',
 'keras',
 'svm',
 'clustering',
 'correlation',
 'probability',
 'deep-learning',
 'forecasting',
 'cross-validation',
 'pca',
 'pandas',
 'numpy',
 'arima']

# %%
results = list()
for query in array_querry:
    query_concat = query + ' python'
    r = ydl.extract_info('ytsearchdate1000:\{}'.format(query_concat), download=False)
    for entry in r['entries']:
        if entry is not None:
            entry['query'] = query
    results += r['entries']

# %%
results = [e for e in results if e is not None]
len(results)
# Out:
# 4382

# %%
df = pd.DataFrame(results)

#columns = ['title', 'upload_date', 'view_count']
df['upload_date'] = pd.to_datetime(df['upload_date'])
df['days_since_publication'] = (pd.to_datetime('2021-01-01') - df['upload_date']) / np.timedelta64(1,'D')

# %%
df.sample(5)
# Out:
#                id                       uploader               uploader_id  \
# 1509  CdHuLGuU2c4                   Engineers.SG  UCjRZr5HQKHVKP3SZdX8y8Qw
# 4277  XYGZ7Cue9aE            TheEngineeringWorld  UCcBIq3zYCbiq3jYWAq45q3w
# 2484  yWkpRdpOiPY                        sentdex                   sentdex
# 3544  LxVzfncBcng                      CloudxLab  UC8mJ6DL1Q32UWyJUceoO8Jw
# 4031  w2LljY52uj4  Cafemática com Prof. Fernando  UCi5sNlRu7u5MaZ5UBsfa8Lw
#
#                                            uploader_url  \
# 1509  http://www.youtube.com/channel/UCjRZr5HQKHVKP3...
# 4277  http://www.youtube.com/channel/UCcBIq3zYCbiq3j...
# 2484                http://www.youtube.com/user/sentdex
# 3544  http://www.youtube.com/channel/UC8mJ6DL1Q32UWy...
# 4031  http://www.youtube.com/channel/UCi5sNlRu7u5MaZ...
#
#                     channel_id  \
# 1509  UCjRZr5HQKHVKP3SZdX8y8Qw
# 4277  UCcBIq3zYCbiq3jYWAq45q3w
# 2484  UCfzlCWGWYyIQ0aLC5w48gBQ
# 3544  UC8mJ6DL1Q32UWyJUceoO8Jw
# 4031  UCi5sNlRu7u5MaZ5UBsfa8Lw
#
#                                             channel_url upload_date  license  \
# 1509  http://www.youtube.com/channel/UCjRZr5HQKHVKP3...  2016-11-08      NaN
# 4277  http://www.youtube.com/channel/UCcBIq3zYCbiq3j...  2018-08-08      NaN
# 2484  http://www.youtube.com/channel/UCfzlCWGWYyIQ0a...  2018-09-18      NaN
# 3544  http://www.youtube.com/channel/UC8mJ6DL1Q32UWy...  2020-04-28      NaN
# 4031  http://www.youtube.com/channel/UCi5sNlRu7u5MaZ...  2020-05-05      NaN
#
#      creator                                              title alt_title  \
# 1509     NaN  PySpark case - using Random Forest for binary ...       NaN
# 4277     NaN  Python NumPy Examples: Universal Functions, Py...       NaN
# 2484     NaN  Cryptocurrency-predicting RNN Model - Deep Lea...       NaN
# 3544     NaN  NumPy & Pandas | Python for Machine Learning |...       NaN
# 4031     NaN  NUMPY | Multiplicação de matrizes Python no Go...       NaN
#
#                                              thumbnails  \
# 1509  [{'url': 'https://i.ytimg.com/vi/CdHuLGuU2c4/h...
# 4277  [{'url': 'https://i.ytimg.com/vi/XYGZ7Cue9aE/h...
# 2484  [{'url': 'https://i.ytimg.com/vi/yWkpRdpOiPY/h...
# 3544  [{'url': 'https://i.ytimg.com/vi/LxVzfncBcng/h...
# 4031  [{'url': 'https://i.ytimg.com/vi/w2LljY52uj4/h...
#
#                                             description  \
# 1509  Speaker: Weimin Wang Synopsis: A binary classi...
# 4277                       In this Jupyterlab Notebook
# 2484  Welcome to the next tutorial covering deep lea...
# 3544                                              This
# 4031  Adicionamos duas matrizes quadradas 3x3 e as m...
#
#                     categories  \
# 1509  ['Science & Technology']
# 4277             ['Education']
# 2484             ['Education']
# 3544             ['Education']
# 4031             ['Education']
#
#                                                    tags subtitles  \
# 1509                         ['engineers', 'singapore']        {}
# 4277  ['python', 'python numpy example', 'numpy func...        {}
# 2484  ['TensorBoard', 'TensorFlow', 'recurrent neura...        {}
# 3544                                                NaN        {}
# 4031  ['Python', 'Numpy', 'numpy array', 'numpy tuto...        {}
#
#      automatic_captions  duration  age_limit  annotations  chapters  \
# 1509                 {}    2551.0          0          NaN       NaN
# 4277                 {}    1015.0          0          NaN       NaN
# 2484                 {}    1386.0          0          NaN       NaN
# 3544                 {}   10796.0          0          NaN       NaN
# 4031                 {}     654.0          0          NaN       NaN
#
#                                       webpage_url  view_count  like_count  \
# 1509  https://www.youtube.com/watch?v=CdHuLGuU2c4           8        99.0
# 4277  https://www.youtube.com/watch?v=XYGZ7Cue9aE           1        16.0
# 2484  https://www.youtube.com/watch?v=yWkpRdpOiPY          76      1253.0
# 3544  https://www.youtube.com/watch?v=LxVzfncBcng           5        31.0
# 4031  https://www.youtube.com/watch?v=w2LljY52uj4           1        63.0
#
#       dislike_count  average_rating  \
# 1509            2.0        4.920792
# 4277            2.0        4.764706
# 2484           22.0        4.930980
# 3544            2.0        4.875000
# 4031            2.0        4.937500
#
#                                                 formats  is_live  start_time  \
# 1509  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 4277  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 2484  [{'format_id': '249', 'url': 'https://r1---sn-...      NaN         NaN
# 3544  [{'format_id': '249', 'url': 'https://r1---sn-...      NaN         NaN
# 4031  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
#
#       end_time  series  season_number  episode_number track artist album  \
# 1509       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 4277       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 2484       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 3544       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 4031       NaN     NaN            NaN             NaN   NaN    NaN   NaN
#
#       release_date  release_year  subscriber_count extractor  \
# 1509           NaN           NaN           16200.0   youtube
# 4277           NaN           NaN           19900.0   youtube
# 2484           NaN           NaN          984000.0   youtube
# 3544           NaN           NaN            9930.0   youtube
# 4031           NaN           NaN           11700.0   youtube
#
#      webpage_url_basename extractor_key  n_entries               playlist  \
# 1509          CdHuLGuU2c4       Youtube        299  \random-forest python
# 4277          XYGZ7Cue9aE       Youtube        479          \numpy python
# 2484          yWkpRdpOiPY       Youtube        493          \keras python
# 3544          LxVzfncBcng       Youtube        508         \pandas python
# 4031          w2LljY52uj4       Youtube        479          \numpy python
#
#                 playlist_id  playlist_title  playlist_uploader  \
# 1509  \random-forest python             NaN                NaN
# 4277          \numpy python             NaN                NaN
# 2484          \keras python             NaN                NaN
# 3544         \pandas python             NaN                NaN
# 4031          \numpy python             NaN                NaN
#
#       playlist_uploader_id  playlist_index  \
# 1509                   NaN             284
# 4277                   NaN             457
# 2484                   NaN             432
# 3544                   NaN             232
# 4031                   NaN             211
#
#                                               thumbnail   display_id  \
# 1509  https://i.ytimg.com/vi_webp/CdHuLGuU2c4/maxres...  CdHuLGuU2c4
# 4277  https://i.ytimg.com/vi_webp/XYGZ7Cue9aE/maxres...  XYGZ7Cue9aE
# 2484  https://i.ytimg.com/vi_webp/yWkpRdpOiPY/maxres...  yWkpRdpOiPY
# 3544  https://i.ytimg.com/vi/LxVzfncBcng/maxresdefau...  LxVzfncBcng
# 4031  https://i.ytimg.com/vi_webp/w2LljY52uj4/maxres...  w2LljY52uj4
#
#       requested_subtitles                                  requested_formats  \
# 1509                  NaN  [{'ext': 'mp4', 'height': 1080, 'format_note':...
# 4277                  NaN  [{'ext': 'webm', 'height': 1080, 'format_note'...
# 2484                  NaN  [{'format_id': '248', 'url': 'https://r1---sn-...
# 3544                  NaN  [{'format_id': '136', 'url': 'https://r1---sn-...
# 4031                  NaN  [{'ext': 'mp4', 'height': 1080, 'format_note':...
#
#                                                  format format_id   ext  \
# 1509  137 - 1920x1080 (DASH video)+140 - audio only ...   137+140   mp4
# 4277  248 - 1920x1080 (DASH video)+251 - audio only ...   248+251  webm
# 2484    248 - 1920x1080 (1080p)+140 - audio only (tiny)   248+140  webm
# 3544      136 - 1280x720 (720p)+251 - audio only (tiny)   136+251   mp4
# 4031  137 - 1920x1080 (DASH video)+251 - audio only ...   137+251   mp4
#
#       width  height  resolution  fps       vcodec  vbr  stretched_ratio  \
# 1509   1920    1080         NaN   30  avc1.64001e  NaN              NaN
# 4277   1920    1080         NaN   30          vp9  NaN              NaN
# 2484   1920    1080         NaN   30          vp9  NaN              NaN
# 3544   1280     720         NaN   25  avc1.4d401f  NaN              NaN
# 4031   1920    1080         NaN   30  avc1.640028  NaN              NaN
#
#          acodec    abr          query  days_since_publication
# 1509  mp4a.40.2  128.0  random-forest                  1515.0
# 4277       opus  160.0          numpy                   877.0
# 2484  mp4a.40.2  128.0          keras                   836.0
# 3544       opus  160.0         pandas                   248.0
# 4031       opus  160.0          numpy                   241.0

# %%
df.columns
# Out:
# Index(['id', 'uploader', 'uploader_id', 'uploader_url', 'channel_id',
#        'channel_url', 'upload_date', 'license', 'creator', 'title',
#        'alt_title', 'thumbnails', 'description', 'categories', 'tags',
#        'subtitles', 'automatic_captions', 'duration', 'age_limit',
#        'annotations', 'chapters', 'webpage_url', 'view_count', 'like_count',
#        'dislike_count', 'average_rating', 'formats', 'is_live', 'start_time',
#        'end_time', 'series', 'season_number', 'episode_number', 'track',
#        'artist', 'album', 'release_date', 'release_year', 'subscriber_count',
#        'extractor', 'webpage_url_basename', 'extractor_key', 'n_entries',
#        'playlist', 'playlist_id', 'playlist_title', 'playlist_uploader',
#        'playlist_uploader_id', 'playlist_index', 'thumbnail', 'display_id',
#        'requested_subtitles', 'requested_formats', 'format', 'format_id',
#        'ext', 'width', 'height', 'resolution', 'fps', 'vcodec', 'vbr',
#        'stretched_ratio', 'acodec', 'abr', 'query', 'days_since_publication'],
#       dtype='object')

# %%
df.head()
# Out:
#             id             uploader               uploader_id  \
# 0  QyYZT8o-f3U               kfsoft                kfsoft3388
# 1  PtBuqAdbpfY          Ahmad Bazzi  UCgC1d4JZ1Fz4t8MWLJD464w
# 2  TD4wCHNhZcU            Fred Feng  UCq3ORM0nCQQX6IY4q-GpJaQ
# 3  XWLnrN2sN78       TechT20 Videos  UCBwm1W3tuiBxYQfB7l5n6WA
# 4  Ip1maupNFjs  Pranav Chippalkatti  UCvAjpIla-l41HKnOtGRfCKg
#
#                                         uploader_url  \
# 0             http://www.youtube.com/user/kfsoft3388
# 1  http://www.youtube.com/channel/UCgC1d4JZ1Fz4t8...
# 2  http://www.youtube.com/channel/UCq3ORM0nCQQX6I...
# 3  http://www.youtube.com/channel/UCBwm1W3tuiBxYQ...
# 4  http://www.youtube.com/channel/UCvAjpIla-l41HK...
#
#                  channel_id  \
# 0  UC9JVMiztp4zLWybGl9v9KIw
# 1  UCgC1d4JZ1Fz4t8MWLJD464w
# 2  UCq3ORM0nCQQX6IY4q-GpJaQ
# 3  UCBwm1W3tuiBxYQfB7l5n6WA
# 4  UCvAjpIla-l41HKnOtGRfCKg
#
#                                          channel_url upload_date  license  \
# 0  http://www.youtube.com/channel/UC9JVMiztp4zLWy...  2020-12-08      NaN
# 1  http://www.youtube.com/channel/UCgC1d4JZ1Fz4t8...  2020-12-08      NaN
# 2  http://www.youtube.com/channel/UCq3ORM0nCQQX6I...  2020-12-08      NaN
# 3  http://www.youtube.com/channel/UCBwm1W3tuiBxYQ...  2020-12-08      NaN
# 4  http://www.youtube.com/channel/UCvAjpIla-l41HK...  2020-12-08      NaN
#
#   creator                                              title alt_title  \
# 0     NaN  Python 初級 - 機器學習：scikit-learn - regression 回歸|...       NaN
# 1     NaN  Ridge Regression | Tikhonov Regularization | M...       NaN
# 2     NaN  Introduction to Machine learning in Python wit...       NaN
# 3     NaN  Installing Python 3.85 (numpy, tensorflow, sci...       NaN
# 4     NaN  'Hands-on session on python using scikit-learn...       NaN
#
#                                           thumbnails  \
# 0  [{'url': 'https://i.ytimg.com/vi/QyYZT8o-f3U/h...
# 1  [{'url': 'https://i.ytimg.com/vi/PtBuqAdbpfY/h...
# 2  [{'url': 'https://i.ytimg.com/vi/TD4wCHNhZcU/h...
# 3  [{'url': 'https://i.ytimg.com/vi/XWLnrN2sN78/h...
# 4  [{'url': 'https://i.ytimg.com/vi/Ip1maupNFjs/h...
#
#                                          description          categories  \
# 0                             Machine Learning with        ['Education']
# 1  About This lecture introduces Ridge Regression...       ['Education']
# 2  This tutorial video was originally made for th...       ['Education']
# 3  Installing_Python #Installing_scikitlearn #Ins...  ['People & Blogs']
# 4                               Hands-on session on   ['People & Blogs']
#
#                                                 tags subtitles  \
# 0  ['python', 'tutorial', 'programming', 'cantone...        {}
# 1  ['ridge regression', 'linear regression', 'mac...        {}
# 2          ['sklearn', 'python', 'machine learning']        {}
# 3  ['#installing python 3.85', 'installing numpy'...        {}
# 4                                                NaN        {}
#
#   automatic_captions  duration  age_limit  annotations  chapters  \
# 0                 {}    6752.0          0          NaN       NaN
# 1                 {}    1181.0          0          NaN       NaN
# 2                 {}    3118.0          0          NaN       NaN
# 3                 {}     534.0          0          NaN       NaN
# 4                 {}    3540.0          0          NaN       NaN
#
#                                    webpage_url  view_count  like_count  \
# 0  https://www.youtube.com/watch?v=QyYZT8o-f3U           1         2.0
# 1  https://www.youtube.com/watch?v=PtBuqAdbpfY          11       639.0
# 2  https://www.youtube.com/watch?v=TD4wCHNhZcU          28         NaN
# 3  https://www.youtube.com/watch?v=XWLnrN2sN78           9         NaN
# 4  https://www.youtube.com/watch?v=Ip1maupNFjs           3         NaN
#
#    dislike_count  average_rating  \
# 0            NaN        5.000000
# 1            7.0        4.956657
# 2            NaN             NaN
# 3            NaN             NaN
# 4            NaN             NaN
#
#                                              formats  is_live  start_time  \
# 0  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 1  [{'format_id': '249', 'url': 'https://r3---sn-...      NaN         NaN
# 2  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 3  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
# 4  [{'ext': 'm4a', 'format_note': 'DASH audio', '...      NaN         NaN
#
#    end_time  series  season_number  episode_number track artist album  \
# 0       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 1       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 2       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 3       NaN     NaN            NaN             NaN   NaN    NaN   NaN
# 4       NaN     NaN            NaN             NaN   NaN    NaN   NaN
#
#    release_date  release_year  subscriber_count extractor  \
# 0           NaN           NaN            6880.0   youtube
# 1           NaN           NaN           47500.0   youtube
# 2           NaN           NaN              12.0   youtube
# 3           NaN           NaN               NaN   youtube
# 4           NaN           NaN             142.0   youtube
#
#   webpage_url_basename extractor_key  n_entries              playlist  \
# 0          QyYZT8o-f3U       Youtube        476  \scikit-learn python
# 1          PtBuqAdbpfY       Youtube        476  \scikit-learn python
# 2          TD4wCHNhZcU       Youtube        476  \scikit-learn python
# 3          XWLnrN2sN78       Youtube        476  \scikit-learn python
# 4          Ip1maupNFjs       Youtube        476  \scikit-learn python
#
#             playlist_id  playlist_title  playlist_uploader  \
# 0  \scikit-learn python             NaN                NaN
# 1  \scikit-learn python             NaN                NaN
# 2  \scikit-learn python             NaN                NaN
# 3  \scikit-learn python             NaN                NaN
# 4  \scikit-learn python             NaN                NaN
#
#    playlist_uploader_id  playlist_index  \
# 0                   NaN               1
# 1                   NaN               2
# 2                   NaN               3
# 3                   NaN               4
# 4                   NaN               5
#
#                                            thumbnail   display_id  \
# 0  https://i.ytimg.com/vi/QyYZT8o-f3U/maxresdefau...  QyYZT8o-f3U
# 1  https://i.ytimg.com/vi_webp/PtBuqAdbpfY/maxres...  PtBuqAdbpfY
# 2  https://i.ytimg.com/vi_webp/TD4wCHNhZcU/maxres...  TD4wCHNhZcU
# 3  https://i.ytimg.com/vi_webp/XWLnrN2sN78/maxres...  XWLnrN2sN78
# 4  https://i.ytimg.com/vi_webp/Ip1maupNFjs/maxres...  Ip1maupNFjs
#
#    requested_subtitles                                  requested_formats  \
# 0                  NaN  [{'ext': 'mp4', 'height': 1080, 'format_note':...
# 1                  NaN  [{'format_id': '302', 'url': 'https://r3---sn-...
# 2                  NaN  [{'ext': 'mp4', 'height': 1080, 'format_note':...
# 3                  NaN  [{'ext': 'webm', 'height': 1080, 'format_note'...
# 4                  NaN  [{'ext': 'webm', 'height': 844, 'format_note':...
#
#                                               format format_id   ext  width  \
# 0  137 - 1920x1080 (DASH video)+251 - audio only ...   137+251   mp4   1920
# 1    302 - 1280x720 (720p60)+140 - audio only (tiny)   302+140  webm   1280
# 2  137 - 1920x1080 (DASH video)+251 - audio only ...   137+251   mp4   1920
# 3  248 - 1920x1080 (DASH video)+251 - audio only ...   248+251  webm   1920
# 4  248 - 1920x844 (DASH video)+140 - audio only (...   248+140  webm   1920
#
#    height  resolution  fps       vcodec  vbr  stretched_ratio     acodec  \
# 0    1080         NaN   28  avc1.640028  NaN              NaN       opus
# 1     720         NaN   60          vp9  NaN              NaN  mp4a.40.2
# 2    1080         NaN   30  avc1.640028  NaN              NaN       opus
# 3    1080         NaN   24          vp9  NaN              NaN       opus
# 4     844         NaN   25          vp9  NaN              NaN  mp4a.40.2
#
#      abr         query  days_since_publication
BSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLD6_cbtMb3TNqoH2WkpoWwHqB7phw', 'width': 246, 'height': 138, 'resolution': '246x138', 'id': '2'}, {'url': 'https://i.ytimg.com/vi/Ip1maupNFjs/hqdefault.jpg?sqp=-oaymwEZCNACELwBSFXyq4qpAwsIARUAAIhCGAFwAQ==&rs=AOn4CLCi2M8uf5ZFeZT-bT77yy3jvq3iGw', 'width': 336, 'height': 188, 'resolution': '336x188', 'id': '3'}, {'url': 'https://i.ytimg.com/vi_webp/Ip1maupNFjs/maxresdefault.webp', 'width': 1920, 'height': 1080, 'resolution': '1920x1080', 'id': '4'}]"]

# %%
columns = ['id', 'uploader', 'upload_date', 'title', 'thumbnails', 'description', 'categories', 'tags',
       'duration', 'view_count', 'like_count', 'dislike_count', 'average_rating', 'is_live']

df[columns].head()
# Out:
#             id             uploader upload_date  \
# 0  QyYZT8o-f3U               kfsoft  2020-12-08
# 1  PtBuqAdbpfY          Ahmad Bazzi  2020-12-08
# 2  TD4wCHNhZcU            Fred Feng  2020-12-08
# 3  XWLnrN2sN78       TechT20 Videos  2020-12-08
# 4  Ip1maupNFjs  Pranav Chippalkatti  2020-12-08
#
#                                                title  \
# 0  Python 初級 - 機器學習：scikit-learn - regression 回歸|...
# 1  Ridge Regression | Tikhonov Regularization | M...
# 2  Introduction to Machine learning in Python wit...
# 3  Installing Python 3.85 (numpy, tensorflow, sci...
# 4  'Hands-on session on python using scikit-learn...
#
#                                           thumbnails  \
# 0  [{'url': 'https://i.ytimg.com/vi/QyYZT8o-f3U/h...
# 1  [{'url': 'https://i.ytimg.com/vi/PtBuqAdbpfY/h...
# 2  [{'url': 'https://i.ytimg.com/vi/TD4wCHNhZcU/h...
# 3  [{'url': 'https://i.ytimg.com/vi/XWLnrN2sN78/h...
# 4  [{'url': 'https://i.ytimg.com/vi/Ip1maupNFjs/h...
#
#                                          description          categories  \
# 0                             Machine Learning with        ['Education']
# 1  About This lecture introduces Ridge Regression...       ['Education']
# 2  This tutorial video was originally made for th...       ['Education']
# 3  Installing_Python #Installing_scikitlearn #Ins...  ['People & Blogs']
# 4                               Hands-on session on   ['People & Blogs']
#
#                                                 tags  duration  view_count  \
# 0  ['python', 'tutorial', 'programming', 'cantone...    6752.0           1
# 1  ['ridge regression', 'linear regression', 'mac...    1181.0          11
# 2          ['sklearn', 'python', 'machine learning']    3118.0          28
# 3  ['#installing python 3.85', 'installing numpy'...     534.0           9
# 4                                                NaN    3540.0           3
#
#    like_count  dislike_count  average_rating  is_live
# 0         2.0            NaN        5.000000      NaN
# 1       639.0            7.0        4.956657      NaN
# 2         NaN            NaN             NaN      NaN
# 3         NaN            NaN             NaN      NaN
# 4         NaN            NaN             NaN      NaN

# %% [markdown]
# # Convert to .csv

# %%
df.to_csv('../Data/youtube_dlc/YouTubeStackExchangeQueryRaw.csv', index=False)
